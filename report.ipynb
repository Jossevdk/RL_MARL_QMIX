# %% [markdown]
# # **Report Group 12**

# %% [markdown]
# #### **Loading packages**

# %%
from datetime import datetime

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import wandb
from gymPacMan import gymPacMan_parallel_env
import torch.nn.functional as F
from collections import deque
import random
import os
from dataclasses import dataclass
import pandas as pd

import cProfile
import pstats

torch.autograd.set_detect_anomaly(True)


if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")

wandb.login(key = '', relogin = True)


from util_functions import *
# Out:
# Running on the GPU
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\josse\_netrc
# Running on the GPU

# %% [markdown]
# # **Section 1: All functions**

# %% [markdown]
# ## **Networks**

# %% [markdown]
# ### Agent networks

# %% [markdown]
# #### CNN

# %%
class AgentQNetwork(nn.Module):
    def __init__(self,obs_shape, action_dim,hidden_dim=64):
        super(AgentQNetwork, self).__init__()
        self.c1 = nn.Conv2d(obs_shape[0], 32, kernel_size=3, stride=1, padding=1)
        self.c2 = nn.Conv2d(32, hidden_dim, kernel_size=3, stride=1, padding=1)
        self.c3 = nn.Conv2d(hidden_dim, 4*hidden_dim, kernel_size=3, stride=1, padding=1)
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Linear(4*hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, action_dim)


    def forward(self, obs):
        x = torch.relu(self.c1(obs))
        x = torch.relu(self.c2(x))
        x = torch.relu(self.c3(x))
        x = self.global_pool(x)
        x = torch.flatten(x, start_dim=1)
        x = torch.relu(self.fc1(x))
        q_values = self.fc2(x)
        return q_values

# %% [markdown]
# #### CNN with attention

# %% [markdown]
# #### LSTM

# %%
# Define the CNN-LSTM-Q Network


class CNNLSTMQNetwork_hidden(nn.Module):
    def __init__(self, embed_dim, obs_shape, action_space):
        super(CNNLSTMQNetwork_hidden, self).__init__()
        self.embed_dim = embed_dim

        # Shared encoder for the agent's state
        self.shared_encoder = nn.Sequential(
            nn.Conv2d(obs_shape[0], 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))  # Adaptive pooling to handle varying input sizes
        )

        # Fully connected layer to project encoded state to embed_dim
        self.fc = nn.Linear(128 * 1 * 1, embed_dim)

        # LSTM layer to model temporal dependencies
        self.lstm = nn.LSTM(embed_dim, embed_dim, num_layers=1, batch_first=True)

        # Final layer to compute Q-values
        self.final_layer = nn.Sequential(
            nn.Linear(embed_dim, action_space),
            nn.SiLU()  # Swish activation
        )

    def forward(self, state, hidden):
        # Process single state using the shared encoder
        cnn_features = []
        for t in range(5):
            
            encoded_state = self.shared_encoder(state[:, t, :, :, :])  # Encode the state
            encoded_state = encoded_state.view(encoded_state.size(0), -1)  # Flatten to [batch_size, 128 * 1 * 1]
            projected_state = self.fc(encoded_state).unsqueeze(1)  # Project to embed_dim and add sequence dimension
            cnn_features.append(projected_state)
            
        cnn_features = torch.cat(cnn_features, dim=1)  # Shape: (batch_size, seq_len, cnn_output_size)
        # Apply LSTM to model temporal dependencies
        hx, cx = hidden[0, :, :, :], hidden[1, :, :, :]
        lstm_out, (hx, cx) = self.lstm(cnn_features, (hx, cx))
        hidden_new = torch.stack([hx.detach(), cx.detach()], dim=0)
        # Use the output of the LSTM for the final layer
        q_values = self.final_layer(lstm_out[:, -1, :])  # Shape: [batch_size, action_space]

        return q_values, hidden_new

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.embed_dim),
                torch.zeros(1, batch_size, self.embed_dim))

# %% [markdown]
# ### Mixing Networks

# %% [markdown]
# #### Simple

# %%
class SimpleQMixer(nn.Module):
    def __init__(self, n_agents, state_shape):
        super(SimpleQMixer, self).__init__()

        self.n_agents = n_agents
        self.state_shape = state_shape
        print(state_shape)
        # Much simpler state processing
        self.state_conv = nn.Sequential(
            nn.Conv3d(state_shape[0], 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv3d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(64 * state_shape[1] * state_shape[2] * state_shape[3],  n_agents)  # Output: (batch_size, 32 * n_agents)
        )
        # Initialize weights positively
        for m in self.state_conv:
            if isinstance(m, nn.Conv3d) or isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)
        # Single layer mixing network
        self.mixing_layer = nn.Linear(n_agents , 1, bias=False)

        # Initialize close to equal weights_enemy
        nn.init.uniform_(self.mixing_layer.weight, 0.9, 1.1)

    def forward(self, agent_qs, states):

        bs = agent_qs.size(0)
        weights_enemy = F.softplus(self.state_conv(states))


        agent_qs = agent_qs.view(-1, 1, self.n_agents)

        weighted_qs = agent_qs * weights_enemy.unsqueeze(1)

        q_tot = self.mixing_layer(weighted_qs.squeeze(1))
        return q_tot.view(bs, -1, 1)

# %% [markdown]
# #### Attention

# %%
class AttentionMixer(nn.Module):
    def __init__(self, n_agents, state_shape=(2, 8, 10, 20), embed_dim=32, n_heads=4):
        super(AttentionMixer, self).__init__()

        self.n_agents = n_agents
        self.state_shape = state_shape[1:]  # Remove agent dimension
        self.embed_dim = embed_dim
        self.n_heads = n_heads

        # Shared Conv2D encoder for each agent
        self.shared_encoder = nn.Sequential(
            nn.Conv2d(self.state_shape[0], 16, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.AdaptiveAvgPool2d(1)
        )

        # Fully connected layer to project to embed_dim
        self.fc = nn.Sequential(
            nn.Linear(64, embed_dim),
            nn.SiLU()  # Swish activation
        )

        for m in self.shared_encoder:
            if isinstance(m, nn.Conv2d):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)
        for m in self.fc:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        # Multi-head attention for inter-agent interaction
        self.attention = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=n_heads, batch_first=True)

        # Hypernetwork for mixing weights_enemy and biases
        self.hyper_w = nn.Sequential(
            nn.Linear(embed_dim * n_agents, embed_dim * embed_dim),
            nn.SiLU(),  # Swish activation
            nn.Linear(embed_dim * embed_dim, n_agents * embed_dim)
        )
        self.hyper_b = nn.Sequential(
            nn.Linear(embed_dim * n_agents, embed_dim),
            nn.SiLU(),  # Swish activation
            nn.Linear(embed_dim, embed_dim)
        )

        # Final layer to compute Q_tot
        self.final_layer = nn.Sequential(
            nn.Linear(embed_dim, 1),
            nn.SiLU()  # Swish activation
        )

        for m in self.hyper_w:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        for m in self.hyper_b:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        for m in self.final_layer:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)


    def forward(self, agent_qs, states):
        batch_size = states.size(0)

        # Process each agent's state individually using the shared encoder
        agent_features = []
        for i in range(self.n_agents):
            agent_state = states[:, i, :, :, :]  # Shape: [batch_size, 8, 10, 20]
            encoded_state = self.shared_encoder(agent_state)  # Encode individual agent
            encoded_state = encoded_state.view(batch_size, -1)  # Flatten to [batch_size, 128]
            projected_state = self.fc(encoded_state)  # Project to embed_dim
            agent_features.append(projected_state)

        # Stack agent features: Shape [batch_size, n_agents, embed_dim]
        agent_features = torch.stack(agent_features, dim=1)

        # Apply attention to model inter-agent interaction
        attention_out, _ = self.attention(agent_features, agent_features, agent_features)

        # Flatten attention output for hypernetwork
        attention_out_flat = attention_out.reshape(batch_size, -1)  # Shape: [batch_size, n_agents * embed_dim]

        # Compute hypernetwork weights and biases
        hyper_w = F.softplus(self.hyper_w(attention_out_flat).view(batch_size, self.n_agents, self.embed_dim))
        hyper_b = self.hyper_b(attention_out_flat).view(batch_size, self.embed_dim)

        # Combine agent Q-values with weights and biases
        agent_qs = agent_qs.view(batch_size, self.n_agents, 1)  # Shape: [batch_size, n_agents, 1]
        weighted_qs = torch.bmm(agent_qs.transpose(1, 2), hyper_w).squeeze(1) + hyper_b

        # Final projection to Q_tot
        q_tot = self.final_layer(weighted_qs).unsqueeze(1)
        return q_tot

# %% [markdown]
# ## **Loss calculations**

# %% [markdown]
# ### IQL

# %%
def compute_td_loss_iql(agent_q_networks, target_q_networks, batch, weights=None, gamma=0.99, lambda_=0.1):
    """
    Computes the TD loss for QMix training using the Huber loss.

    Args:
        agent_q_networks (list): List of Q-networks for each agent.
        mixing_network (SimpleQMixer): The mixing network to compute global Q-values.
        target_q_networks (list): List of target Q-networks for each agent.
        batch (tuple): A batch of experiences (states, actions, rewards, next_states, dones).
        weights (torch.Tensor): Importance sampling weights (optional).
        gamma (float): Discount factor for future rewards.
        lambda_ (float): Regularization factor for stability.

    Returns:
        torch.Tensor: Total loss for training.
    """
    states, actions, rewards, next_states, dones = batch

    # Convert to tensors and move to device
    states = torch.tensor(states, dtype=torch.float32).to(device)
    actions = torch.tensor(actions, dtype=torch.long).to(device)
    rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
    next_states = torch.tensor(next_states, dtype=torch.float32).to(device)
    dones = torch.tensor(dones, dtype=torch.float32).to(device)

    # Current Q-values for each agent
    agent_q_values = []
    for agent_index, q_net in enumerate(agent_q_networks):
        q_vals = q_net(states[:, agent_index, :, :, :])  # Get Q-values for each agent
        agent_q_values.append(
            q_vals.gather(dim=1, index=actions[:, agent_index].unsqueeze(1)))  # Select Q-value for taken action
    agent_q_values = torch.cat(agent_q_values, dim=1)  # Shape: (batch_size, n_agents)

    # Target Q-values using Double DQN
    with torch.no_grad():
        # Get actions from current Q-networks
        next_agent_q_values = []
        for agent_index, (q_net, target_net) in enumerate(zip(agent_q_networks, target_q_networks)):
            next_q_vals = q_net(next_states[:, agent_index, :, :, :])  # Get Q-values from current network
            max_next_actions = next_q_vals.argmax(dim=1, keepdim=True)  # Greedy actions
            target_q_vals = target_net(next_states[:, agent_index, :, :, :])  # Get Q-values from target network\
            max_next_q_vals = target_q_vals.gather(1, max_next_actions)
            done_mask = dones[:, 0, 0].unsqueeze(1)
            filtered_target_q_vals = max_next_q_vals * (1 - done_mask)

            next_agent_q_values.append(filtered_target_q_vals)  # Use target Q-values for selected actions
        next_agent_q_values = torch.cat(next_agent_q_values, dim=1)  # Shape: (batch_size, n_agents)

    # Independent Q-learning target for each agent (all members of the blue team receive the same reward)
    target_q = rewards[:, 0, 0].unsqueeze(1) + gamma * next_agent_q_values

    # Compute Huber loss, try also with MSE loss
    loss_fn = torch.nn.HuberLoss()

    loss_agent1 = loss_fn(agent_q_values[:, 0], target_q[:, 0])
    loss_agent2 = loss_fn(agent_q_values[:, 1], target_q[:, 1])

    return loss_agent1, loss_agent2

# %% [markdown]
# ### Mixed Q-Learning

# %% [markdown]
# ### Mixed Q-Learning for LSTM

# %% [markdown]
# ## **Replay buffers**

# %% [markdown]
# ### Normal buffer

# %%
class ReplayBuffer:
    def __init__(self, buffer_size=10000):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        experiences = random.sample(self.buffer, batch_size)

        # Restructure the batch into separate arrays for states, actions, rewards, next_states, and dones
        states = np.array([exp[0].cpu().numpy() for exp in experiences], dtype=np.float32)
        actions = np.array([exp[1] for exp in experiences], dtype=np.int64)
        rewards = np.array([exp[2] for exp in experiences])
        next_states = np.array([exp[3].cpu().numpy() for exp in experiences])
        dones = np.array([exp[4] for exp in experiences])

        return states, actions, rewards, next_states, dones

    def size(self):
        return len(self.buffer)

# %% [markdown]
# ### Experience buffer

# %% [markdown]
# ### Buffer for sequences

# %%
class ReplayBuffer_sequence:
    def __init__(self, buffer_size=10000, sequence_length=5):
        self.buffer = deque(maxlen=buffer_size)
        self.sequence_length = sequence_length

    def add(self, experience):
        self.buffer.append(experience)
        
    def sample(self, batch_size):
        sequences = []
        for _ in range(batch_size):
            start_index = random.randint(0, len(self.buffer) - self.sequence_length)
            sequence = [self.buffer[i] for i in range(start_index, start_index + self.sequence_length)]
            sequences.append(sequence)
        
        # Transpose the sequences to get batches of each component
        
        states = torch.stack([torch.stack([torch.stack(seq[0]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        actions = torch.stack([torch.stack([torch.tensor(seq[1]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        rewards = torch.stack([torch.stack([torch.tensor(seq[2]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        next_states = torch.stack([torch.stack([torch.stack(seq[3]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        terminations = torch.stack([torch.stack([torch.tensor(seq[4], dtype=torch.int).to(device) for seq in sequence]) for sequence in sequences], dim=2)
        hidden_states = torch.cat([sequence[-1][5] for sequence in sequences], dim = -2).to(device)
        next_hidden_states = torch.cat([sequence[-1][6] for sequence in sequences], dim = -2).to(device)
        
        return (states, actions, rewards, next_states, terminations, hidden_states, next_hidden_states)

    def size(self):
        return len(self.buffer)

# %% [markdown]
# ## Utility functions

# %% [markdown]
# !!! Also see 'util_functions.py' !!!

# %%
# Adjusted epsilon-greedy action function
def epsilon_greedy_action(agent_q_network, state, epsilon, legal_actions, exploring = True):
    
    if random.random() < epsilon and exploring:
        # Explore: take a random action
        print("random action")
        action = random.choice(legal_actions)
    else:
        print("network action")
        state = state.unsqueeze(0).to(device)  # Add batch dimension
        q_values = agent_q_network(state)
        q_values = q_values.cpu().detach().numpy()
        action = np.random.choice(np.flatnonzero(q_values == q_values.max()))

    return action


def update_target_network(agent_q_networks, target_q_networks):
    for target, source in zip(target_q_networks, agent_q_networks):
        target.load_state_dict(source.state_dict())



def interpolate_weights(start_weights, end_weights, factor):
    return [(1 - factor) * start + factor * end for start, end in zip(start_weights, end_weights)]

def get_dynamic_weights(episode, n_episodes):
    # Define the initial weights for the beginning, middle, and end
    weights_beginning = [1, 0, 0, 0, 0, 0]
    weights_middle = [0, 0.33, 0.34, 0.33, 0, 0]
    weights_end = [0, 0, 0, 0, 0.5, 0.5]

    # Calculate the transition points
    transition1 = n_episodes // 3
    transition2 = 2 * n_episodes // 3

    # Adjust weights based on the current episode
    if episode < transition1:
        factor = episode / transition1
        return interpolate_weights(weights_beginning, weights_middle, factor)
    elif episode < transition2:
        factor = (episode - transition1) / (transition2 - transition1)
        return interpolate_weights(weights_middle, weights_end, factor)
    else:
        factor = (episode - transition2) / (n_episodes - transition2)
        return interpolate_weights(weights_middle, weights_end, factor)
    

import os

def create_folder_if_not_exists(folder_path):
    os.makedirs(folder_path, exist_ok=True)

# %% [markdown]
# # **Section 2: Training loops**

# %% [markdown]
# ## IQL

# %%
def train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p, learn_p, random_enemy=False, schedule=False, later_exploration = False):
    
    optimizer = optim.Adam([param for net in agent_q_networks for param in net.parameters()], lr=learn_p.lr_agent)
    #mixing_optimizer = optim.Adam(mixing_network.parameters(), lr=learn_p.lr_mixing)
    if schedule:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=learn_p.gamma)
        #scheduler_mix = torch.optim.lr.scheduler.ExponentialLR(mixing_optimizer, gamma=learn_p.learn_gamma)
   
    n_episodes = train_p.n_episodes
    batch_size = train_p.batch_size
    gamma = train_p.gamma
    epsilon = train_p.epsilon  # Initial exploration probability
    epsilon_min = train_p.epsilon_min
    epsilon_decay = train_p.epsilon_decay
    target_update_frequency = train_p.target_update_frequency

    
    
    legal_actions = [0, 1, 2, 3, 4]
    agent_indexes = [1, 3]
    episode_rewards = []
    win_rates = []
    enemieName = env.enemieName
    if random_enemy:
        enemylist = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']
        weights_enemy = get_dynamic_weights(0, n_episodes)
        enemieName = np.random.choice(enemylist, p=weights_enemy)

    create_folder_if_not_exists(name_experiment)

    for episode in range(n_episodes):
        steps_counter = 0
        print(f"enemy: {enemieName}")

        done = {agent_id: False for agent_id in agent_indexes}
        if random_enemy:
            weights_enemy = get_dynamic_weights(episode, n_episodes)
            enemieName = np.random.choice(enemylist, p=weights_enemy)
        env.reset(enemieName=enemieName)
        blue_player1_reward = 0
        blue_player2_reward = 0
        score = 0
        if later_exploration:
            exploring = False
        else:
            exploring = True
        while not all(done.values()):
            if later_exploration and steps_counter > 10:
                exploring = True
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []
            for i, agent_index in enumerate(agent_indexes):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                action = epsilon_greedy_action(agent_q_networks[i], state, epsilon, legal_actions, exploring)
                actions[agent_index] = action



            next_states, rewards, terminations, info = env.step(actions)
            score -= info["score_change"]
            done = {key: value for key, value in terminations.items() if key in agent_indexes}
            blue_player1_reward += rewards[1]
            blue_player2_reward += rewards[3]

            next_states_converted = []
            rewards_converted = []
            terminations_converted = []
            actions_converted = []

            for index in agent_indexes:
                next_states_converted.append(list(next_states.values())[index])
                rewards_converted.append(rewards[index])
                terminations_converted.append(terminations[index])
                actions_converted.append(actions[index])

            next_states_converted = torch.stack(next_states_converted)
            states_converted = torch.stack(states)
            rewards_converted = [rewards_converted]
            terminations_converted = [terminations_converted]
            replay_buffer.add(
                (states_converted, actions_converted, rewards_converted, next_states_converted, terminations_converted))

            if replay_buffer.size() >= batch_size:
                batch = replay_buffer.sample(batch_size)
                loss1, loss2 = compute_td_loss_iql(agent_q_networks, target_q_networks, batch,
                                               gamma=gamma)
                wandb.log({"loss1": loss1})
                wandb.log({"loss2": loss2})

                # Zero gradients for all optimizers
                optimizer.zero_grad()

                # Backpropagate once for all losses
                loss1.backward(retain_graph=True)
                loss2.backward()

                # Update weights
                optimizer.step()
                if schedule:
                    scheduler.step()
                    wandb.log({"lr": optimizer.param_groups[0]['lr']})

            steps_counter += 1
        wandb.log({"epsilon": epsilon})
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        wandb.log({"blue_player1_reward": blue_player1_reward})
        wandb.log({"blue_player2_reward": blue_player2_reward})
        wandb.log({"episode": episode})
        wandb.log({'score': score})




        if (episode + 1) % target_update_frequency == 0:
            update_target_network(agent_q_networks, target_q_networks)
        
        if (episode) % target_update_frequency == 0:
            torch.save(agent_q_networks[0].state_dict(),f'{name_experiment}/agent1_{episode+1}.pth')
            torch.save(agent_q_networks[1].state_dict(),f'{name_experiment}/agent3_{episode+1}.pth')
         # Log rewards and win rates
        episode_rewards.append(blue_player1_reward+blue_player2_reward)
        print(blue_player1_reward)
        print(blue_player2_reward)
        print(f"Episode reward: {blue_player1_reward+blue_player2_reward}")

        if np.sum(env.game.state.getBlueFood().data) == 0:
            win_rates.append(1)
        else:
            win_rates.append(0)

        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(episode_rewards[-10:])
            avg_win_rate = np.mean(win_rates[-10:])
            print(f"Episode {episode + 1}/{n_episodes}, Average Reward: {avg_reward:.2f}, Win Rate: {avg_win_rate:.2f}")

    # Plot rewards and win rates
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(episode_rewards, label="Average Reward")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title("Average Reward per Episode")
    plt.legend()

    plt.subplot(1, 2, 2)
    smoothed_win_rates = np.convolve(win_rates, np.ones(10)/10, mode='valid') if len(win_rates) > 10 else win_rates
    plt.plot(smoothed_win_rates, label="Win Rate (Smoothed)")
    plt.xlabel("Episode")
    plt.ylabel("Win Rate")
    plt.title("Win Rate Over Episodes")
    plt.legend()

    plt.tight_layout()
    plt.show()

    print("Training completed.")

# %%
def train_qmix():
    pass

# %%
def train_qmix_LSTM():
    pass

# %%
def train_PPO():
    pass

# %% [markdown]
# # **Section 3: Testing and conclusions**

# %% [markdown]
# ## Testing IQL

# %% [markdown]
# First 300 steps with random enemy on win.lay with fixed lr

# %%
@dataclass
class train_param:
    n_episodes: int = 600
    batch_size: int = 32
    gamma: float = 0.995
    epsilon: float = 0.95
    epsilon_min: float = 0.1
    epsilon_decay: float = 0.995
    target_update_frequency: int = 10

@dataclass
class learn_param:
    lr_mix: float = 0.0001
    lr_agent: float = 0.0001
    gamma: float = 0.99995

#TODO: specific net_param for each network architecture
@dataclass
class net_param_CNN:
    hidden_dim: int = 64
    

train_p = train_param()
learn_p = learn_param()
net_p = net_param_CNN()

# %%
env = gymPacMan_parallel_env(display=True, layout_file="layouts/win.lay", length=200, enemieName='randomTeam.py', defenceReward=True)
# Out:
# Loaded layout from file
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts

# %%
n_agents = 2
action_dim = 5

obs_individual_agent = env.get_Observation(0)
obs_shape = obs_individual_agent.shape

agent_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p.hidden_dim).to(device) for _ in range(n_agents)]
target_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p.hidden_dim).to(device) for _ in range(n_agents)]
update_target_network(agent_q_networks, target_q_networks)

replay_buffer = ReplayBuffer()

# %%
name_experiment ='IQL_CNN_win'
wandb.init(project="", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")

train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p, learn_p, random_enemy=False)
wandb.finish()
# Out:
# Tracking run with wandb version 0.19.0
# Run data is saved locally in <code>c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\wandb\run-20241210_104501-IQL_CNN_win__20241210_104501</code>
# Syncing run <strong><a href='https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_win__20241210_104501' target="_blank">IQL_CNN_win__20241210_104501</a></strong> to <a href='https://wandb.ai/josse-vdk/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/josse-vdk/uncategorized' target="_blank">https://wandb.ai/josse-vdk/uncategorized</a>
#  View run at <a href='https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_win__20241210_104501' target="_blank">https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_win__20241210_104501</a>
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# C:\Users\josse\AppData\Local\Temp\ipykernel_14928\558125621.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
# 6.309999999999964
# 6.309999999999964
# Episode reward: 12.619999999999928
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 17.869999999999965
# 17.869999999999965
# Episode reward: 35.73999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.86
# 13.86
# Episode reward: 27.72
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.919999999999998
# 13.919999999999998
# Episode reward: 27.839999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.799999999999992
# 4.799999999999992
# Episode reward: 9.599999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.0
# 4.0
# Episode reward: 8.0
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.949999999999979
# 4.949999999999979
# Episode reward: 9.899999999999958
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.799999999999995
# 4.799999999999995
# Episode reward: 9.59999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.129999999999999
# 15.129999999999999
# Episode reward: 30.259999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 16.25999999999998
# 16.25999999999998
# Episode reward: 32.51999999999996
# Episode 10/300, Average Reward: 20.38, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.939999999999984
# 4.939999999999984
# Episode reward: 9.879999999999969
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.919999999999986
# 4.919999999999986
# Episode reward: 9.839999999999971
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 5.919999999999984
# 5.919999999999984
# Episode reward: 11.839999999999968
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.5499999999999865
# 4.5499999999999865
# Episode reward: 9.099999999999973
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.639999999999985
# 4.639999999999985
# Episode reward: 9.27999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.620000000000001
# 13.620000000000001
# Episode reward: 27.240000000000002
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.179999999999998
# 15.179999999999998
# Episode reward: 30.359999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.84
# 14.84
# Episode reward: 29.68
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 0.3499999999999721
# 0.3499999999999721
# Episode reward: 0.6999999999999442
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.029999999999994
# 15.029999999999994
# Episode reward: 30.059999999999988
# Episode 20/300, Average Reward: 16.80, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 15.189999999999994
# 15.189999999999994
# Episode reward: 30.37999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 5.42999999999998
# 5.42999999999998
# Episode reward: 10.85999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.34
# 14.34
# Episode reward: 28.68
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.479999999999997
# 14.479999999999997
# Episode reward: 28.959999999999994
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.92
# 13.92
# Episode reward: 27.84
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.03
# 13.03
# Episode reward: 26.06
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.79
# 12.79
# Episode reward: 25.58
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.77999999999999
# 15.77999999999999
# Episode reward: 31.55999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.92
# 13.92
# Episode reward: 27.84
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 6.099999999999969
# 6.099999999999969
# Episode reward: 12.199999999999937
# Episode 30/300, Average Reward: 25.00, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.44
# 13.44
# Episode reward: 26.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.14
# 13.14
# Episode reward: 26.28
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.339999999999995
# 15.339999999999995
# Episode reward: 30.67999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.59
# 13.59
# Episode reward: 27.18
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 16.369999999999973
# 16.369999999999973
# Episode reward: 32.739999999999945
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.739999999999997
# 14.739999999999997
# Episode reward: 29.479999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 5.969999999999988
# 5.969999999999988
# Episode reward: 11.939999999999976
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.54
# 13.54
# Episode reward: 27.08
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.95
# 13.95
# Episode reward: 27.9
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.319999999999986
# 4.319999999999986
# Episode reward: 8.639999999999972
# Episode 40/300, Average Reward: 24.88, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.120000000000001
# 13.120000000000001
# Episode reward: 26.240000000000002
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.54
# 13.54
# Episode reward: 27.08
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.869999999999997
# 13.869999999999997
# Episode reward: 27.739999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.29
# 13.29
# Episode reward: 26.58
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.019999999999998
# 14.019999999999998
# Episode reward: 28.039999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.18
# 13.18
# Episode reward: 26.36
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.749999999999996
# 14.749999999999996
# Episode reward: 29.499999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# -1.34000000000001
# -1.34000000000001
# Episode reward: -2.68000000000002
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.62
# 12.62
# Episode reward: 25.24
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.319999999999986
# 4.319999999999986
# Episode reward: 8.639999999999972
# Episode 50/300, Average Reward: 22.27, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.08
# 13.08
# Episode reward: 26.16
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.799999999999992
# 14.799999999999992
# Episode reward: 29.599999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.309999999999999
# 13.309999999999999
# Episode reward: 26.619999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.3
# 13.3
# Episode reward: 26.6
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.789999999999997
# 13.789999999999997
# Episode reward: 27.579999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.899999999999995
# 14.899999999999995
# Episode reward: 29.79999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.709999999999997
# 13.709999999999997
# Episode reward: 27.419999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.119999999999996
# 14.119999999999996
# Episode reward: 28.23999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.709999999999997
# 13.709999999999997
# Episode reward: 27.419999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.1999999999999895
# 4.1999999999999895
# Episode reward: 8.399999999999979
# Episode 60/300, Average Reward: 25.78, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.82
# 12.82
# Episode reward: 25.64
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.689999999999998
# 13.689999999999998
# Episode reward: 27.379999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.97
# 12.97
# Episode reward: 25.94
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.219999999999992
# 4.219999999999992
# Episode reward: 8.439999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.469999999999995
# 14.469999999999995
# Episode reward: 28.93999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.8199999999999856
# 3.8199999999999856
# Episode reward: 7.639999999999971
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# -2.7300000000000018
# -2.7300000000000018
# Episode reward: -5.4600000000000035
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.37
# 13.37
# Episode reward: 26.74
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.079999999999989
# 4.079999999999989
# Episode reward: 8.159999999999979
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.9899999999999745
# 4.9899999999999745
# Episode reward: 9.979999999999949
# Episode 70/300, Average Reward: 16.34, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.679999999999998
# 13.679999999999998
# Episode reward: 27.359999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.229999999999986
# 4.229999999999986
# Episode reward: 8.459999999999972
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.759999999999998
# 14.759999999999998
# Episode reward: 29.519999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.979999999999997
# 3.979999999999997
# Episode reward: 7.959999999999994
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.899999999999997
# 13.899999999999997
# Episode reward: 27.799999999999994
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.259999999999998
# 13.259999999999998
# Episode reward: 26.519999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.61
# 13.61
# Episode reward: 27.22
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.769999999999978
# 4.769999999999978
# Episode reward: 9.539999999999957
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.609999999999996
# 14.609999999999996
# Episode reward: 29.21999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.719999999999999
# 13.719999999999999
# Episode reward: 27.439999999999998
# Episode 80/300, Average Reward: 22.10, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.629999999999988
# 15.629999999999988
# Episode reward: 31.259999999999977
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.059999999999993
# 15.059999999999993
# Episode reward: 30.119999999999987
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.21
# 13.21
# Episode reward: 26.42
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.429999999999989
# 4.429999999999989
# Episode reward: 8.859999999999978
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.939999999999996
# 14.939999999999996
# Episode reward: 29.879999999999992
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.519999999999996
# 13.519999999999996
# Episode reward: 27.039999999999992
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.059999999999999
# 13.059999999999999
# Episode reward: 26.119999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 5.149999999999986
# 5.149999999999986
# Episode reward: 10.299999999999972
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.09
# 13.09
# Episode reward: 26.18
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.2099999999999875
# 4.2099999999999875
# Episode reward: 8.419999999999975
# Episode 90/300, Average Reward: 22.46, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.929999999999986
# 3.929999999999986
# Episode reward: 7.859999999999972
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.389999999999997
# 13.389999999999997
# Episode reward: 26.779999999999994
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 5.849999999999975
# 5.849999999999975
# Episode reward: 11.69999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.489999999999995
# 13.489999999999995
# Episode reward: 26.97999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.149999999999993
# 14.149999999999993
# Episode reward: 28.299999999999986
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.44
# 13.44
# Episode reward: 26.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.25
# 13.25
# Episode reward: 26.5
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 15.01999999999999
# 15.01999999999999
# Episode reward: 30.03999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.159999999999993
# 14.159999999999993
# Episode reward: 28.319999999999986
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.04999999999999
# 15.04999999999999
# Episode reward: 30.09999999999998
# Episode 100/300, Average Reward: 24.35, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.16
# 13.16
# Episode reward: 26.32
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.209999999999994
# 14.209999999999994
# Episode reward: 28.419999999999987
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.95
# 12.95
# Episode reward: 25.9
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.44
# 12.44
# Episode reward: 24.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.229999999999995
# 14.229999999999995
# Episode reward: 28.45999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.269999999999998
# 13.269999999999998
# Episode reward: 26.539999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 15.279999999999994
# 15.279999999999994
# Episode reward: 30.559999999999988
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.9
# 12.9
# Episode reward: 25.8
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.009999999999993
# 14.009999999999993
# Episode reward: 28.019999999999985
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.639999999999999
# 14.639999999999999
# Episode reward: 29.279999999999998
# Episode 110/300, Average Reward: 27.42, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.0699999999999954
# 3.0699999999999954
# Episode reward: 6.139999999999991
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.81
# 12.81
# Episode reward: 25.62
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.280000000000001
# 13.280000000000001
# Episode reward: 26.560000000000002
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.109999999999991
# 4.109999999999991
# Episode reward: 8.219999999999983
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.6499999999999884
# 3.6499999999999884
# Episode reward: 7.299999999999977
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.44
# 14.44
# Episode reward: 28.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.65999999999999
# 14.65999999999999
# Episode reward: 29.31999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.59
# 12.59
# Episode reward: 25.18
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.17
# 13.17
# Episode reward: 26.34
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.18
# 13.18
# Episode reward: 26.36
# Episode 120/300, Average Reward: 20.99, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.299999999999999
# 13.299999999999999
# Episode reward: 26.599999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.67
# 12.67
# Episode reward: 25.34
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 15.349999999999989
# 15.349999999999989
# Episode reward: 30.699999999999978
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# -1.810000000000013
# -1.810000000000013
# Episode reward: -3.620000000000026
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.509999999999994
# 13.509999999999994
# Episode reward: 27.01999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.7
# 12.7
# Episode reward: 25.4
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.279999999999996
# 13.279999999999996
# Episode reward: 26.55999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.7999999999999905
# 3.7999999999999905
# Episode reward: 7.599999999999981
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.89
# 12.89
# Episode reward: 25.78
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.039999999999994
# 14.039999999999994
# Episode reward: 28.079999999999988
# Episode 130/300, Average Reward: 21.95, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.43
# 12.43
# Episode reward: 24.86
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.259999999999998
# 14.259999999999998
# Episode reward: 28.519999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.88
# 12.88
# Episode reward: 25.76
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.15
# 13.15
# Episode reward: 26.3
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.04
# 13.04
# Episode reward: 26.08
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.85
# 12.85
# Episode reward: 25.7
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.379999999999999
# 13.379999999999999
# Episode reward: 26.759999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.96
# 12.96
# Episode reward: 25.92
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.659999999999988
# 15.659999999999988
# Episode reward: 31.319999999999975
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.039999999999996
# 14.039999999999996
# Episode reward: 28.07999999999999
# Episode 140/300, Average Reward: 26.93, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.909999999999993
# 13.909999999999993
# Episode reward: 27.819999999999986
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.949999999999992
# 13.949999999999992
# Episode reward: 27.899999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# -1.9400000000000088
# -1.9400000000000088
# Episode reward: -3.8800000000000177
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.739999999999988
# 14.739999999999988
# Episode reward: 29.479999999999976
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# -2.2500000000000067
# -2.2500000000000067
# Episode reward: -4.500000000000013
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.7499999999999947
# 3.7499999999999947
# Episode reward: 7.499999999999989
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.77
# 12.77
# Episode reward: 25.54
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.45
# 13.45
# Episode reward: 26.9
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.699999999999983
# 4.699999999999983
# Episode reward: 9.399999999999967
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.98
# 12.98
# Episode reward: 25.96
# Episode 150/300, Average Reward: 17.21, Win Rate: 0.20
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.949999999999992
# 13.949999999999992
# Episode reward: 27.899999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.869999999999989
# 14.869999999999989
# Episode reward: 29.739999999999977
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.7199999999999918
# 3.7199999999999918
# Episode reward: 7.4399999999999835
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.85
# 12.85
# Episode reward: 25.7
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.369999999999994
# 14.369999999999994
# Episode reward: 28.739999999999988
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.82
# 12.82
# Episode reward: 25.64
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.66
# 12.66
# Episode reward: 25.32
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.299999999999988
# 3.299999999999988
# Episode reward: 6.599999999999976
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.81
# 12.81
# Episode reward: 25.62
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.419999999999998
# 13.419999999999998
# Episode reward: 26.839999999999996
# Episode 160/300, Average Reward: 22.95, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.899999999999988
# 3.899999999999988
# Episode reward: 7.799999999999976
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.459999999999997
# 13.459999999999997
# Episode reward: 26.919999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.1399999999999912
# 3.1399999999999912
# Episode reward: 6.2799999999999825
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.17
# 13.17
# Episode reward: 26.34
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.42999999999999
# 3.42999999999999
# Episode reward: 6.85999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.1799999999999864
# 3.1799999999999864
# Episode reward: 6.359999999999973
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.229999999999992
# 14.229999999999992
# Episode reward: 28.459999999999983
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# -3.509999999999999
# -3.509999999999999
# Episode reward: -7.019999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.759999999999998
# 13.759999999999998
# Episode reward: 27.519999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.709999999999985
# 4.709999999999985
# Episode reward: 9.41999999999997
# Episode 170/300, Average Reward: 13.89, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.469999999999986
# 14.469999999999986
# Episode reward: 28.939999999999973
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.319999999999999
# 13.319999999999999
# Episode reward: 26.639999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.489999999999998
# 13.489999999999998
# Episode reward: 26.979999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.83
# 12.83
# Episode reward: 25.66
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.84
# 12.84
# Episode reward: 25.68
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.01
# 13.01
# Episode reward: 26.02
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.209999999999999
# 13.209999999999999
# Episode reward: 26.419999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.89
# 12.89
# Episode reward: 25.78
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.8
# 12.8
# Episode reward: 25.6
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.86
# 12.86
# Episode reward: 25.72
# Episode 180/300, Average Reward: 26.34, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.57
# 12.57
# Episode reward: 25.14
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.669999999999989
# 4.669999999999989
# Episode reward: 9.339999999999979
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.849999999999996
# 13.849999999999996
# Episode reward: 27.699999999999992
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.629999999999999
# 12.629999999999999
# Episode reward: 25.259999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.339999999999998
# 14.339999999999998
# Episode reward: 28.679999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.83
# 12.83
# Episode reward: 25.66
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.419999999999996
# 14.419999999999996
# Episode reward: 28.839999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.4099999999999975
# 3.4099999999999975
# Episode reward: 6.819999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.73
# 13.73
# Episode reward: 27.46
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# -3.0
# -3.0
# Episode reward: -6.0
# Episode 190/300, Average Reward: 19.89, Win Rate: 0.20
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.5899999999999856
# 3.5899999999999856
# Episode reward: 7.179999999999971
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.28999999999999
# 15.28999999999999
# Episode reward: 30.57999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.899999999999996
# 3.899999999999996
# Episode reward: 7.799999999999992
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.51
# 13.51
# Episode reward: 27.02
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.129999999999999
# 13.129999999999999
# Episode reward: 26.259999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.3899999999999895
# 3.3899999999999895
# Episode reward: 6.779999999999979
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.719999999999992
# 4.719999999999992
# Episode reward: 9.439999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.18
# 14.18
# Episode reward: 28.36
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.76
# 12.76
# Episode reward: 25.52
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.6399999999999966
# 3.6399999999999966
# Episode reward: 7.279999999999993
# Episode 200/300, Average Reward: 17.62, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.4099999999999997
# 3.4099999999999997
# Episode reward: 6.819999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.649999999999984
# 15.649999999999984
# Episode reward: 31.29999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.030000000000001
# 13.030000000000001
# Episode reward: 26.060000000000002
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.7999999999999923
# 3.7999999999999923
# Episode reward: 7.5999999999999845
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.439999999999998
# 13.439999999999998
# Episode reward: 26.879999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.579999999999998
# 13.579999999999998
# Episode reward: 27.159999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.78
# 12.78
# Episode reward: 25.56
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.419999999999995
# 14.419999999999995
# Episode reward: 28.83999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 15.299999999999995
# 15.299999999999995
# Episode reward: 30.59999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.629999999999999
# 12.629999999999999
# Episode reward: 25.259999999999998
# Episode 210/300, Average Reward: 23.61, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.2099999999999875
# 3.2099999999999875
# Episode reward: 6.419999999999975
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.5199999999999765
# 4.5199999999999765
# Episode reward: 9.039999999999953
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.209999999999994
# 4.209999999999994
# Episode reward: 8.419999999999987
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.439999999999984
# 4.439999999999984
# ...
# Arguments: {}
# Red team starts
# 13.579999999999998
# 13.579999999999998
# Episode reward: 27.159999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.61
# 12.61
# Episode reward: 25.22
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.2
# 13.2
# Episode reward: 26.4
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.47
# 13.47
# Episode reward: 26.94
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.1
# 13.1
# Episode reward: 26.2
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.68
# 12.68
# Episode reward: 25.36
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.479999999999997
# 13.479999999999997
# Episode reward: 26.959999999999994
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.74
# 12.74
# Episode reward: 25.48
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.14
# 13.14
# Episode reward: 26.28
# Episode 240/300, Average Reward: 26.20, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.62
# 12.62
# Episode reward: 25.24
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.13
# 13.13
# Episode reward: 26.26
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.02
# 13.02
# Episode reward: 26.04
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.45
# 12.45
# Episode reward: 24.9
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 4.079999999999986
# 4.079999999999986
# Episode reward: 8.159999999999972
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.27
# 13.27
# Episode reward: 26.54
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.98
# 12.98
# Episode reward: 25.96
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.209999999999999
# 13.209999999999999
# Episode reward: 26.419999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.58
# 12.58
# Episode reward: 25.16
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.37
# 12.37
# Episode reward: 24.74
# Episode 250/300, Average Reward: 23.94, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.8699999999999877
# 3.8699999999999877
# Episode reward: 7.739999999999975
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.599999999999992
# 3.599999999999992
# Episode reward: 7.199999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.579999999999997
# 14.579999999999997
# Episode reward: 29.159999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.59
# 12.59
# Episode reward: 25.18
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.429999999999983
# 3.429999999999983
# Episode reward: 6.859999999999966
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.56
# 12.56
# Episode reward: 25.12
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.49
# 12.49
# Episode reward: 24.98
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.68
# 12.68
# Episode reward: 25.36
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.64
# 12.64
# Episode reward: 25.28
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.99
# 12.99
# Episode reward: 25.98
# Episode 260/300, Average Reward: 20.29, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.58
# 13.58
# Episode reward: 27.16
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 3.3299999999999867
# 3.3299999999999867
# Episode reward: 6.6599999999999735
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.58
# 12.58
# Episode reward: 25.16
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.149999999999999
# 13.149999999999999
# Episode reward: 26.299999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.249999999999996
# 13.249999999999996
# Episode reward: 26.499999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 5.309999999999983
# 5.309999999999983
# Episode reward: 10.619999999999965
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.85
# 12.85
# Episode reward: 25.7
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.29
# 13.29
# Episode reward: 26.58
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.07
# 13.07
# Episode reward: 26.14
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.96
# 12.96
# Episode reward: 25.92
# Episode 270/300, Average Reward: 22.67, Win Rate: 0.10
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.41
# 12.41
# Episode reward: 24.82
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.55
# 12.55
# Episode reward: 25.1
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.98
# 12.98
# Episode reward: 25.96
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.65
# 12.65
# Episode reward: 25.3
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.94
# 12.94
# Episode reward: 25.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.169999999999992
# 4.169999999999992
# Episode reward: 8.339999999999984
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.42
# 12.42
# Episode reward: 24.84
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.239999999999998
# 13.239999999999998
# Episode reward: 26.479999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.6
# 12.6
# Episode reward: 25.2
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.559999999999999
# 12.559999999999999
# Episode reward: 25.119999999999997
# Episode 280/300, Average Reward: 23.70, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 13.129999999999999
# 13.129999999999999
# Episode reward: 26.259999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.74
# 12.74
# Episode reward: 25.48
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.94
# 12.94
# Episode reward: 25.88
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 2.729999999999994
# 2.729999999999994
# Episode reward: 5.459999999999988
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.5
# 12.5
# Episode reward: 25.0
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.85
# 12.85
# Episode reward: 25.7
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.79
# 12.79
# Episode reward: 25.58
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 3.7299999999999964
# 3.7299999999999964
# Episode reward: 7.459999999999993
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.86
# 12.86
# Episode reward: 25.72
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.48
# 12.48
# Episode reward: 24.96
# Episode 290/300, Average Reward: 21.75, Win Rate: 0.00
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 4.489999999999985
# 4.489999999999985
# Episode reward: 8.97999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.43
# 12.43
# Episode reward: 24.86
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.02
# 13.02
# Episode reward: 26.04
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 14.849999999999998
# 14.849999999999998
# Episode reward: 29.699999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.52
# 12.52
# Episode reward: 25.04
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.52
# 12.52
# Episode reward: 25.04
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 13.51
# 13.51
# Episode reward: 27.02
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 12.42
# 12.42
# Episode reward: 24.84
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# 12.42
# 12.42
# Episode reward: 24.84
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# 14.399999999999999
# 14.399999999999999
# Episode reward: 28.799999999999997
# Episode 300/300, Average Reward: 24.52, Win Rate: 0.00
# Training completed.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>blue_player1_reward</td><td>▄▇██▇▇▇▇▃▇▇▃▃▇█▃▇▃██▇▃▁▇▇█▇▃▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>blue_player2_reward</td><td>▇▃▇▇█▁▇▇▇▄▇▇▇▇▇▇▇▇▇▃▇▃▇▃▇▃▇▇▇▇▇▇▇▇▇▇▆▇▇▆</td></tr><tr><td>episode</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>epsilon</td><td>███▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁</td></tr><tr><td>loss1</td><td>▁▁▁▃▁▃▁█▂▅▂▃▃▁▂▁▁▃▃▁▁▁▁▁▁▂▁▁▁▃▆▃▁▁▂▂▁▁▂▃</td></tr><tr><td>loss2</td><td>▁▁▁▅▁▁▁▁▄█▁▁▃▁▄▁▁▂▁▁▆▁▂▁▁▁▁▁▁▁▁▁▁▁▆▁▁▁▁▁</td></tr><tr><td>score</td><td>████████▆███████████▅█▆▆▃█▆██▆█████▁█▃██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>blue_player1_reward</td><td>14.4</td></tr><tr><td>blue_player2_reward</td><td>14.4</td></tr><tr><td>episode</td><td>299</td></tr><tr><td>epsilon</td><td>0.21224</td></tr><tr><td>loss1</td><td>0.04211</td></tr><tr><td>loss2</td><td>0.26507</td></tr><tr><td>score</td><td>2</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">IQL_CNN_win__20241210_104501</strong> at: <a href='https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_win__20241210_104501' target="_blank">https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_win__20241210_104501</a><br/> View project at: <a href='https://wandb.ai/josse-vdk/uncategorized' target="_blank">https://wandb.ai/josse-vdk/uncategorized</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20241210_104501-IQL_CNN_win__20241210_104501\logs</code>

# %% [markdown]
# IQL on tiny with random enemy with scheduled learning_rate

# %%
replay_buffer = ReplayBuffer()
name_experiment ='IQL_CNN_tiny'
train_p.epsilon = 0.55
env = gymPacMan_parallel_env(display=True, layout_file="layouts/tinyCapture.lay", length=200, enemieName='randomTeam.py', defenceReward=True)
wandb.init(project="", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")

train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p, learn_p, random_enemy=False, schedule = True, later_exploration = True)
wandb.finish()
# Out:
# Loaded layout from file
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# C:\Users\josse\AppData\Local\Temp\ipykernel_14928\3622664894.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# 2.279999999999998
# 2.279999999999998
# Episode reward: 4.559999999999996
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# 2.659999999999996
# 2.659999999999996
# Episode reward: 5.319999999999992
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# 2.6499999999999977
# 2.6499999999999977
# Episode reward: 5.299999999999995
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# 12.06999999999999
# 12.06999999999999
# Episode reward: 24.13999999999998
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# 3.1899999999999915
# 3.1899999999999915
# Episode reward: 6.379999999999983
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# 3.059999999999994
# 3.059999999999994
# Episode reward: 6.119999999999988
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# 2.659999999999995
# 2.659999999999995
# Episode reward: 5.31999999999999
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# ...
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# 2.4999999999999987
# 2.4999999999999987
# Episode reward: 4.999999999999997
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# 8.669999999999991
# 8.669999999999991
# Episode reward: 17.339999999999982
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# random action
# network action
# random action
# network action
# random action
# random action
# random action
# random action
# network action
# random action
# random action
# network action
# random action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# 3.1199999999999943
# 3.1199999999999943
# Episode reward: 6.239999999999989
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# network action
# network action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# network action
# network action
# random action
# random action
# random action
# random action
# network action
# network action
# network action
# network action
# random action
# random action
# network action
# random action
# network action
# random action
# network action

# %%
wandb.finish()
# Out:
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>blue_player1_reward</td><td>▁▁█▁</td></tr><tr><td>blue_player2_reward</td><td>▁▁█▁</td></tr><tr><td>episode</td><td>▁▃▆█</td></tr><tr><td>epsilon</td><td>█▆▃▁</td></tr><tr><td>loss1</td><td>▂▁▁▁▂▄▆▂▁▅▁▃▁▁▂▅▂▅▁▂▁▂▁▁▁▁▁▁▁▅▁▂▁▂▁▁▁▂▃█</td></tr><tr><td>loss2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▇▃▅█▁▅▇█▅▆▃▁█▂▂▁▁▁▁</td></tr><tr><td>lr</td><td>█▆▆▅▅▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█████</td></tr><tr><td>score</td><td>▁▅█▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>blue_player1_reward</td><td>2.4</td></tr><tr><td>blue_player2_reward</td><td>2.4</td></tr><tr><td>episode</td><td>3</td></tr><tr><td>epsilon</td><td>0.93582</td></tr><tr><td>loss1</td><td>0.20285</td></tr><tr><td>loss2</td><td>0.00817</td></tr><tr><td>lr</td><td>0.0001</td></tr><tr><td>score</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">IQL_CNN_tiny__20241210_114003</strong> at: <a href='https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_tiny__20241210_114003' target="_blank">https://wandb.ai/josse-vdk/uncategorized/runs/IQL_CNN_tiny__20241210_114003</a><br/> View project at: <a href='https://wandb.ai/josse-vdk/uncategorized' target="_blank">https://wandb.ai/josse-vdk/uncategorized</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20241210_114003-IQL_CNN_tiny__20241210_114003\logs</code>

# %%
import pandas as pd

# Define the list of enemies
enemies = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']

# Initialize results dictionary
results = {enemy: {'wins': 0, 'losses': 0, 'draws': 0} for enemy in enemies}

# Number of games to play against each enemy
num_games = 10

# Function to evaluate the agent against an enemy
def evaluate_agent(env, enemy_name, num_games):
    wins, losses, draws = 0, 0, 0
    for _ in range(num_games):
        env.reset(enemieName=enemy_name)
        done = False
        while not done:
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []
            for i, agent_index in enumerate([1,3]):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                state = state.unsqueeze(0).to(device)  # Add batch dimension
                q_values = agent_q_networks[i](state)
                q_values = q_values.cpu().detach().numpy()
                action = np.random.choice(np.flatnonzero(q_values == q_values.max()))
                actions[agent_index] = action
            next_state, reward, done, info = env.step(actions)
            if done:
                if info['result'] == 'win':
                    wins += 1
                elif info['result'] == 'loss':
                    losses += 1
                else:
                    draws += 1
    return wins, losses, draws

# Evaluate the agent against each enemy
for enemy in enemies:
    env = gymPacMan_parallel_env(display=False, layout_file="layouts/smallCapture.lay", length=200, enemieName=enemy, defenceReward=True)
    wins, losses, draws = evaluate_agent(env, enemy, num_games)
    results[enemy]['wins'] = wins
    results[enemy]['losses'] = losses
    results[enemy]['draws'] = draws

# Convert results to a DataFrame for better display
results_df = pd.DataFrame(results).T
print(results_df)

# %% [markdown]
# **Testing idea's**
#
# - experience buffer
# - only exploration after first 10 steps
# -
