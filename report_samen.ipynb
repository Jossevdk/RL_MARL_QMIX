# %% [markdown]
# # **Report Group 12**

# %% [markdown]
# #### **Loading packages**

# %%
from datetime import datetime

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import wandb
from gymPacMan import gymPacMan_parallel_env
import torch.nn.functional as F
from collections import deque
import random
import os
from dataclasses import dataclass
import pandas as pd

import cProfile
import pstats

torch.autograd.set_detect_anomaly(True)


if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")

wandb.login(key = '', relogin = True)
team_name = 'RL_PacMan'

from util_functions import *
# Out:
# Running on the GPU
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\josse\_netrc
# Running on the GPU

# %% [markdown]
# # **Section 1: All functions**

# %% [markdown]
# ## **Networks**

# %% [markdown]
# ### Agent networks

# %% [markdown]
# #### CNN

# %%
class AgentQNetwork(nn.Module):
    def __init__(self,obs_shape, action_dim,hidden_dim=64):
        super(AgentQNetwork, self).__init__()
        self.c1 = nn.Conv2d(obs_shape[0], 32, kernel_size=3, stride=1, padding=1)
        self.c2 = nn.Conv2d(32, hidden_dim, kernel_size=3, stride=1, padding=1)
        self.c3 = nn.Conv2d(hidden_dim, 4*hidden_dim, kernel_size=3, stride=1, padding=1)
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Linear(4*hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, action_dim)


    def forward(self, obs):
        x = torch.relu(self.c1(obs))
        x = torch.relu(self.c2(x))
        x = torch.relu(self.c3(x))
        x = self.global_pool(x)
        x = torch.flatten(x, start_dim=1)
        x = torch.relu(self.fc1(x))
        q_values = self.fc2(x)
        return q_values

# %% [markdown]
# #### CNN with attention

# %% [markdown]
# #### LSTM

# %%
# Define the CNN-LSTM-Q Network


class CNNLSTMQNetwork_hidden(nn.Module):
    def __init__(self, embed_dim, obs_shape, action_space):
        super(CNNLSTMQNetwork_hidden, self).__init__()
        self.embed_dim = embed_dim

        # Shared encoder for the agent's state
        self.shared_encoder = nn.Sequential(
            nn.Conv2d(obs_shape[0], 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))  # Adaptive pooling to handle varying input sizes
        )

        # Fully connected layer to project encoded state to embed_dim
        self.fc = nn.Linear(128 * 1 * 1, embed_dim)

        # LSTM layer to model temporal dependencies
        self.lstm = nn.LSTM(embed_dim, embed_dim, num_layers=1, batch_first=True)

        # Final layer to compute Q-values
        self.final_layer = nn.Sequential(
            nn.Linear(embed_dim, action_space),
            nn.SiLU()  # Swish activation
        )

    def forward(self, state, hidden):
        # Process single state using the shared encoder
        cnn_features = []
        for t in range(5):
            
            encoded_state = self.shared_encoder(state[:, t, :, :, :])  # Encode the state
            encoded_state = encoded_state.view(encoded_state.size(0), -1)  # Flatten to [batch_size, 128 * 1 * 1]
            projected_state = self.fc(encoded_state).unsqueeze(1)  # Project to embed_dim and add sequence dimension
            cnn_features.append(projected_state)
            
        cnn_features = torch.cat(cnn_features, dim=1)  # Shape: (batch_size, seq_len, cnn_output_size)
        # Apply LSTM to model temporal dependencies
        hx, cx = hidden[0, :, :, :], hidden[1, :, :, :]
        lstm_out, (hx, cx) = self.lstm(cnn_features, (hx, cx))
        hidden_new = torch.stack([hx.detach(), cx.detach()], dim=0)
        # Use the output of the LSTM for the final layer
        q_values = self.final_layer(lstm_out[:, -1, :])  # Shape: [batch_size, action_space]

        return q_values, hidden_new

    def init_hidden(self, batch_size):
        return (torch.zeros(1, batch_size, self.embed_dim),
                torch.zeros(1, batch_size, self.embed_dim))

# %% [markdown]
# ### Mixing Networks

# %% [markdown]
# #### Simple

# %%
class SimpleQMixer(nn.Module):
    def __init__(self, n_agents, state_shape):
        """
        Simple QMIX Mixing Network with Convolutional layers.
        Args:
            n_agents (int): Number of agents.
            state_shape (tuple): Shape of the agent-specific input (n_agents, channels, H, W).
        """
        super(SimpleQMixer, self).__init__()
        
        self.n_agents = n_agents
        self.state_shape = state_shape

        self.conv = nn.Sequential(
            nn.Conv2d(state_shape[1], 16, kernel_size=3, stride=1, padding=1),  # state_shape[1] = number of channels
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU()
        )
        
        dummy_input = torch.zeros(1, state_shape[1], state_shape[2], state_shape[3])  # [batch_size=1, channels, H, W]
        conv_output_size = self.conv(dummy_input).view(1, -1).size(1)
        
        # Hypernetwork layers
        self.hyper_w = nn.Sequential(
            nn.Linear(conv_output_size * n_agents, 64),
            nn.ReLU(),
            nn.Linear(64, n_agents)
        )
        
        self.hyper_b = nn.Sequential(
            nn.Linear(conv_output_size * n_agents, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, agent_qs, agent_states):
        """
        Forward pass for the mixing network with Convolutional layers.
        Args:
            agent_qs (torch.Tensor): Tensor of shape [batch_size, n_agents] containing Q-values for each agent.
            agent_states (torch.Tensor): Tensor of shape [batch_size, n_agents, channels, H, W].
        Returns:
            torch.Tensor: Global Q-value of shape [batch_size, 1].
        """
        batch_size, num_agents, channels, height, width = agent_states.shape
        
        agent_states_r = agent_states.view(batch_size * num_agents, channels, height, width)  # [batch_size * n_agents, channels, H, W]
        
        conv_features = self.conv(agent_states_r)  # [batch_size * n_agents, conv_channels, H, W]
        flattened_features = conv_features.view(batch_size, num_agents, -1)  # [batch_size, n_agents, conv_output_size]
        
        combined_features = flattened_features.view(batch_size, -1)  # [batch_size, n_agents * conv_output_size]
        
        w = torch.abs(self.hyper_w(combined_features)).view(batch_size, self.n_agents, 1)
        b = self.hyper_b(combined_features).view(batch_size, 1, 1)
        
        mixed_qs = torch.bmm(agent_qs.unsqueeze(1), w).squeeze(1) + b
        
        return mixed_qs

# %% [markdown]
# #### Attention

# %%
class AttentionMixer(nn.Module):
    def __init__(self, n_agents, state_shape=(2, 8, 10, 20), embed_dim=32, n_heads=4):
        super(AttentionMixer, self).__init__()

        self.n_agents = n_agents
        self.state_shape = state_shape[1:]  # Remove agent dimension
        self.embed_dim = embed_dim
        self.n_heads = n_heads

        # Shared Conv2D encoder for each agent
        self.shared_encoder = nn.Sequential(
            nn.Conv2d(self.state_shape[0], 16, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding='same'),
            nn.SiLU(),  # Swish activation
            nn.AdaptiveAvgPool2d(1)
        )

        # Fully connected layer to project to embed_dim
        self.fc = nn.Sequential(
            nn.Linear(64, embed_dim),
            nn.SiLU()  # Swish activation
        )

        for m in self.shared_encoder:
            if isinstance(m, nn.Conv2d):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)
        for m in self.fc:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        # Multi-head attention for inter-agent interaction
        self.attention = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=n_heads, batch_first=True)

        # Hypernetwork for mixing weights_enemy and biases
        self.hyper_w = nn.Sequential(
            nn.Linear(embed_dim * n_agents, embed_dim * embed_dim),
            nn.SiLU(),  # Swish activation
            nn.Linear(embed_dim * embed_dim, n_agents * embed_dim)
        )
        self.hyper_b = nn.Sequential(
            nn.Linear(embed_dim * n_agents, embed_dim),
            nn.SiLU(),  # Swish activation
            nn.Linear(embed_dim, embed_dim)
        )

        # Final layer to compute Q_tot
        self.final_layer = nn.Sequential(
            nn.Linear(embed_dim, 1),
            nn.SiLU()  # Swish activation
        )

        for m in self.hyper_w:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        for m in self.hyper_b:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)

        for m in self.final_layer:
            if isinstance(m, nn.Linear):
                nn.init.uniform_(m.weight, 0.9, 1.1)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.1)


    def forward(self, agent_qs, states):
        batch_size = states.size(0)

        # Process each agent's state individually using the shared encoder
        agent_features = []
        for i in range(self.n_agents):
            agent_state = states[:, i, :, :, :]  # Shape: [batch_size, 8, 10, 20]
            encoded_state = self.shared_encoder(agent_state)  # Encode individual agent
            encoded_state = encoded_state.view(batch_size, -1)  # Flatten to [batch_size, 128]
            projected_state = self.fc(encoded_state)  # Project to embed_dim
            agent_features.append(projected_state)

        # Stack agent features: Shape [batch_size, n_agents, embed_dim]
        agent_features = torch.stack(agent_features, dim=1)

        # Apply attention to model inter-agent interaction
        attention_out, _ = self.attention(agent_features, agent_features, agent_features)

        # Flatten attention output for hypernetwork
        attention_out_flat = attention_out.reshape(batch_size, -1)  # Shape: [batch_size, n_agents * embed_dim]

        # Compute hypernetwork weights and biases
        hyper_w = F.softplus(self.hyper_w(attention_out_flat).view(batch_size, self.n_agents, self.embed_dim))
        hyper_b = self.hyper_b(attention_out_flat).view(batch_size, self.embed_dim)

        # Combine agent Q-values with weights and biases
        agent_qs = agent_qs.view(batch_size, self.n_agents, 1)  # Shape: [batch_size, n_agents, 1]
        weighted_qs = torch.bmm(agent_qs.transpose(1, 2), hyper_w).squeeze(1) + hyper_b

        # Final projection to Q_tot
        q_tot = self.final_layer(weighted_qs).unsqueeze(1)
        return q_tot

# %% [markdown]
# ## **Loss calculations**

# %% [markdown]
# ### IQL

# %%
def compute_td_loss_iql(agent_q_networks, target_q_networks, batch, weights=None, gamma=0.99, lambda_=0.1):
    """
    Computes the TD loss for QMix training using the Huber loss.

    Args:
        agent_q_networks (list): List of Q-networks for each agent.
        mixing_network (SimpleQMixer): The mixing network to compute global Q-values.
        target_q_networks (list): List of target Q-networks for each agent.
        batch (tuple): A batch of experiences (states, actions, rewards, next_states, dones).
        weights (torch.Tensor): Importance sampling weights (optional).
        gamma (float): Discount factor for future rewards.
        lambda_ (float): Regularization factor for stability.

    Returns:
        torch.Tensor: Total loss for training.
    """
    states, actions, rewards, next_states, dones = batch

    # Convert to tensors and move to device
    states = torch.tensor(states, dtype=torch.float32).to(device)
    actions = torch.tensor(actions, dtype=torch.long).to(device)
    rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
    next_states = torch.tensor(next_states, dtype=torch.float32).to(device)
    dones = torch.tensor(dones, dtype=torch.float32).to(device)

    # Current Q-values for each agent
    agent_q_values = []
    for agent_index, q_net in enumerate(agent_q_networks):
        q_vals = q_net(states[:, agent_index, :, :, :])  # Get Q-values for each agent
        agent_q_values.append(
            q_vals.gather(dim=1, index=actions[:, agent_index].unsqueeze(1)))  # Select Q-value for taken action
    agent_q_values = torch.cat(agent_q_values, dim=1)  # Shape: (batch_size, n_agents)

    # Target Q-values using Double DQN
    with torch.no_grad():
        # Get actions from current Q-networks
        next_agent_q_values = []
        for agent_index, (q_net, target_net) in enumerate(zip(agent_q_networks, target_q_networks)):
            next_q_vals = q_net(next_states[:, agent_index, :, :, :])  # Get Q-values from current network
            max_next_actions = next_q_vals.argmax(dim=1, keepdim=True)  # Greedy actions
            target_q_vals = target_net(next_states[:, agent_index, :, :, :])  # Get Q-values from target network\
            max_next_q_vals = target_q_vals.gather(1, max_next_actions)
            done_mask = dones[:, 0, 0].unsqueeze(1)
            filtered_target_q_vals = max_next_q_vals * (1 - done_mask)

            next_agent_q_values.append(filtered_target_q_vals)  # Use target Q-values for selected actions
        next_agent_q_values = torch.cat(next_agent_q_values, dim=1)  # Shape: (batch_size, n_agents)

    # Independent Q-learning target for each agent (all members of the blue team receive the same reward)
    target_q = rewards[:, 0, 0].unsqueeze(1) + gamma * next_agent_q_values

    # Compute Huber loss, try also with MSE loss
    loss_fn = torch.nn.HuberLoss()

    loss_agent1 = loss_fn(agent_q_values[:, 0], target_q[:, 0])
    loss_agent2 = loss_fn(agent_q_values[:, 1], target_q[:, 1])

    return loss_agent1, loss_agent2

# %% [markdown]
# ### Mixed Q-Learning

# %%
def compute_td_loss_qmix(agent_q_networks, target_q_networks, mixing_network, batch, weights = None, gamma=0.99, lambda_=0.1):
    states, actions, rewards, next_states, dones = batch

    # Convert to tensors and move to device
    states = torch.tensor(states, dtype=torch.float32).to(device)
    actions = torch.tensor(actions, dtype=torch.long).to(device)
    rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
    next_states = torch.tensor(next_states, dtype=torch.float32).to(device)
    dones = torch.tensor(dones, dtype=torch.float32).to(device)

     # Get current Q-values for each agent
    agent_qs = []
    for i, agent_q_network in enumerate(agent_q_networks):
        agent_q = agent_q_network(states[:, i, :, :, :])  # Shape: (batch_size, num_actions)
        agent_q = agent_q.gather(dim=1, index=actions[:,i].unsqueeze(1))  # Select action Q-values
        agent_qs.append(agent_q)
    agent_qs = torch.cat(agent_qs, dim=1)  # Shape: (batch_size, n_agents)
    # Get target Q-values for each agent using Double DQN
    with torch.no_grad():
        target_agent_qs = []
        for i, (agent_q_network, target_q_network) in enumerate(
            zip(agent_q_networks, target_q_networks)
        ):
            # Double DQN: Get greedy actions from the current network
            next_q_values = agent_q_network(next_states[:, i, :, :, :])  # Shape: (batch_size, num_actions)
            greedy_actions = torch.argmax(next_q_values, dim=1, keepdim=True)
            # Get target Q-values using the target network
            target_q_values = target_q_network(next_states[:, i, :, :, :])  # Shape: (batch_size, num_actions)
            target_q = target_q_values.gather(1, greedy_actions)
            done_mask = dones[:, 0, 0].unsqueeze(1)
            filtered_target_q = target_q * (1 - done_mask)
            target_agent_qs.append(filtered_target_q)
        target_agent_qs = torch.cat(target_agent_qs, dim=1)  # Shape: (batch_size, n_agents)

        # Compute the total target Q-value using the mixing network
        target_q_tot = mixing_network(target_agent_qs, next_states).squeeze(1)   # Shape: (batch_size, 1)
    target_q_tot = rewards.sum(dim=2) + gamma * target_q_tot

    
    # Compute the global Q-value using the mixing network
    q_tot = mixing_network(agent_qs, states).squeeze(1)  # Shape: (batch_size, 1)
    # Compute Huber loss
    td_loss = F.huber_loss(target_q_tot, q_tot,  reduction="none")

    # Apply weights if prioritized experience replay is used
    if weights is not None:
        weights = torch.tensor(weights, dtype=torch.float32).to(device)
        td_loss *= weights
        


    # Return the mean loss
    total_loss = td_loss.mean()
    return total_loss

# %% [markdown]
# ### Mixed Q-Learning for LSTM

# %% [markdown]
# ## **Replay buffers**

# %% [markdown]
# ### Normal buffer

# %%
class ReplayBuffer:
    def __init__(self, buffer_size=10000):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        experiences = random.sample(self.buffer, batch_size)

        # Restructure the batch into separate arrays for states, actions, rewards, next_states, and dones
        states = np.array([exp[0].cpu().numpy() for exp in experiences], dtype=np.float32)
        actions = np.array([exp[1] for exp in experiences], dtype=np.int64)
        rewards = np.array([exp[2] for exp in experiences])
        next_states = np.array([exp[3].cpu().numpy() for exp in experiences])
        dones = np.array([exp[4] for exp in experiences])

        return states, actions, rewards, next_states, dones

    def size(self):
        return len(self.buffer)

# %% [markdown]
# ### Prioritized buffer

# %%
import numpy as np

class SumTree:
    """
    A Binary Sum Tree data structure for efficient sampling and priority updates.
    Each leaf node holds a priority, and internal nodes store the sum of leaves.
    """
    def __init__(self, capacity):
        self.capacity = capacity
        # Tree structure:
        # The tree is represented by an array. For a binary tree:
        # - The leaf nodes start at index `size` (which is `capacity`).
        # - For node i, children are at indices 2*i and 2*i+1.
        self.tree = np.zeros(2 * capacity, dtype=np.float32)  # sum tree
        self.data_pointer = 0
    
    def add(self, p):
        # Add a new priority at the leaf node
        idx = self.data_pointer + self.capacity
        self.update(idx, p)
        self.data_pointer = (self.data_pointer + 1) % self.capacity
    
    def update(self, idx, p):
        # Update the priority at the leaf node `idx`
        change = p - self.tree[idx]
        self.tree[idx] = p
        
        # Propagate the change up the tree
        idx //= 2
        while idx >= 1:
            self.tree[idx] += change
            idx //= 2

    def total_priority(self):
        # The root node stores the total sum of all priorities
        return self.tree[1]

    def get_leaf(self, s):
        # Get leaf index, priority given a cumulative sum `s`
        idx = 1
        while idx < self.capacity:  # while not a leaf node
            left = 2 * idx
            right = left + 1
            if s <= self.tree[left]:
                idx = left
            else:
                s -= self.tree[left]
                idx = right
        # Return leaf index, and priority
        return idx, self.tree[idx]

    def __len__(self):
        return self.capacity

# %%
class MultiAgentPrioritizedReplayBufferTree:
    def __init__(self, buffer_size=10000, state_shape=(2,8,20,20), num_agents=2, alpha=0.6, beta_start=0.4, beta_frames=100000, device='cuda'):
        self.buffer_size = buffer_size
        self.alpha = alpha
        self.num_agents = num_agents
        self.device = device

        # Beta schedule parameters
        self.beta_start = beta_start
        self.beta_frames = beta_frames
        self.frame = 1

        # Preallocate memory
        # Assuming states: shape (num_agents, height, width)
        self.states = np.zeros((buffer_size, *state_shape), dtype=np.float32)
        self.next_states = np.zeros((buffer_size, *state_shape), dtype=np.float32)
        self.actions = np.zeros((buffer_size, num_agents), dtype=np.int64)
        self.rewards = np.zeros((buffer_size, 1, 2), dtype=np.float32)
        self.dones = np.zeros((buffer_size, 1, 2), dtype=np.float32)

        self.count = 0
        self.pos = 0

        # Priority tree
        self.tree = SumTree(buffer_size)
        self.max_priority = 1.0  # Max priority for newly inserted transitions

    def _beta_by_frame(self):
        # Linearly increase beta from beta_start to 1.0 over beta_frames
        return min(1.0, self.beta_start + (1.0 - self.beta_start) * self.frame / self.beta_frames)

    def size(self):
        return self.count

    def add(self, experience):
        state, action, reward, next_state, done = experience
        if torch.is_tensor(state):
            state = state.cpu().numpy()
        if torch.is_tensor(next_state):
            next_state = next_state.cpu().numpy()

        self.states[self.pos] = state
        self.next_states[self.pos] = next_state
        self.actions[self.pos] = action
        self.rewards[self.pos] = reward
        self.dones[self.pos] = done

        # Add with max priority (ensures new experiences are likely to be sampled)
        self.tree.add(self.max_priority)

        self.pos = (self.pos + 1) % self.buffer_size
        self.count = min(self.count + 1, self.buffer_size)

    def sample(self, batch_size, q_networks, target_networks):
        beta = self._beta_by_frame()
        self.frame += 1

        # Sample based on priority
        indices = np.zeros(batch_size, dtype=np.int32)
        priorities = np.zeros(batch_size, dtype=np.float32)
        segment = self.tree.total_priority() / batch_size

        for i in range(batch_size):
            s = np.random.uniform(segment * i, segment * (i + 1))
            idx, p = self.tree.get_leaf(s)
            # Leaf index to data index:
            data_index = idx - self.buffer_size
            indices[i] = data_index
            priorities[i] = p

        # Compute weights
        sampling_probabilities = priorities / self.tree.total_priority()
        weights = (self.count * sampling_probabilities) ** (-beta)
        weights /= weights.max()  # Normalize

        # Gather samples
        states_batch = self.states[indices]
        actions_batch = self.actions[indices]
        rewards_batch = self.rewards[indices]
        next_states_batch = self.next_states[indices]
        dones_batch = self.dones[indices]

        # Convert to torch tensors
        states_batch_t = torch.tensor(states_batch, dtype=torch.float32, device=self.device)
        actions_batch_t = torch.tensor(actions_batch, dtype=torch.long, device=self.device)
        rewards_batch_t = torch.tensor(rewards_batch, dtype=torch.float32, device=self.device)
        next_states_batch_t = torch.tensor(next_states_batch, dtype=torch.float32, device=self.device)
        dones_batch_t = torch.tensor(dones_batch, dtype=torch.float32, device=self.device)
        weights_t = torch.tensor(weights, dtype=torch.float32, device=self.device).unsqueeze(1)

        # Compute TD errors for sampled transitions
        td_errors = self.compute_td_errors(
            states_batch_t, actions_batch_t, rewards_batch_t,
            next_states_batch_t, dones_batch_t, q_networks, target_networks
        ).detach().cpu().numpy()

        # Update priorities incrementally
        new_priorities = np.max(td_errors, axis=1) + 1e-6
        self.update_priorities(indices, new_priorities)

        return states_batch_t, actions_batch_t, rewards_batch_t, next_states_batch_t, dones_batch_t, weights_t, indices

    def update_priorities(self, indices, priorities):
        # Update priorities in the sum tree
        for idx, p in zip(indices, priorities):
            # Clip the priority to prevent numerical issues
            p = np.max(p, axis=0) + 1e-6
            self.tree.update(idx + self.buffer_size, p)
            self.max_priority = max(self.max_priority, p)

    def compute_td_errors(self, states, actions, rewards, next_states, dones, q_networks, target_networks):
        # Calculate TD errors for each sampled transition
        with torch.no_grad():
            agent_q_values = []
            target_q_values = []

            for agent_idx in range(self.num_agents):
                # Current Q-values for chosen actions
                q_vals = q_networks[agent_idx](states[:, agent_idx:agent_idx+1, :, :].squeeze(1)) 
                q_taken = q_vals.gather(dim=1, index=actions[:, agent_idx].unsqueeze(1))

                # Target Q-values for next states (Double Q-Learning)
                next_q_vals_target = target_networks[agent_idx](next_states[:, agent_idx:agent_idx+1, :, :].squeeze(1))
                next_q_vals = q_networks[agent_idx](next_states[:, agent_idx:agent_idx+1, :, :].squeeze(1))

                # Choose greedy action from next_q_vals
                greedy_actions = next_q_vals.argmax(dim=1, keepdim=True)
                q_target = next_q_vals_target.gather(dim=1, index=greedy_actions)

                agent_q_values.append(q_taken)
                target_q_values.append(q_target)

            agent_q_values = torch.cat(agent_q_values, dim=1)  # (batch, num_agents)
            target_q_values = torch.cat(target_q_values, dim=1) # (batch, num_agents)

            # TD error: abs(R + gamma * Q_target - Q_current)
            # Assuming a single-step return for simplicity, modify if needed
            gamma = 0.99
            td_error = torch.abs(rewards + (1 - dones) * gamma * target_q_values - agent_q_values)
            return td_error

# %%
class MultiAgentPrioritizedReplayBuffer:
    def __init__(self, buffer_size=10000, alpha=0.6, num_agents=2):
        self.buffer = deque(maxlen=buffer_size)
        self.alpha = alpha
        self.num_agents = num_agents

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size, beta=0.4, q_networks=None, target_networks=None):

        states = np.array([exp[0].cpu().numpy() for exp in self.buffer], dtype=np.float32)
        actions = np.array([exp[1] for exp in self.buffer], dtype=np.int64)
        rewards = np.array([exp[2] for exp in self.buffer])
        next_states = np.array([exp[3].cpu().numpy() for exp in self.buffer])
        dones = np.array([exp[4] for exp in self.buffer])
        td_errors = self.compute_td_errors(states,actions,rewards,next_states,q_networks, target_networks)

        priorities = np.max(td_errors, axis=1) + 1e-6
        print(priorities.shape)
        probabilities = priorities ** self.alpha
        probabilities /= probabilities.sum()
        print(probabilities.shape)
        print(len(self.buffer))

        indices = np.random.choice(len(self.buffer), batch_size, p=probabilities)
        experiences = [self.buffer[idx] for idx in indices]

        weights = ((len(self.buffer) * probabilities[indices]) ** -beta).reshape(32, 1)

        states_batch, actions_batch, rewards_batch, next_states_batch, terminations_batch = zip(*experiences)
        states_batch = np.array([x.cpu().numpy() for x in states_batch], dtype=np.float32)
        actions_batch = np.array([x for x in actions_batch], dtype=np.int64)
        rewards_batch = np.array([x for x in rewards_batch], dtype=np.float32)
        next_states_batch = np.array([x.cpu().numpy() for x in next_states_batch], dtype=np.float32)
        terminations_batch = np.array([x for x in terminations_batch], dtype=np.float32)

        return states_batch, actions_batch, rewards_batch, next_states_batch, terminations_batch, weights

    def compute_td_errors(self, state, action, reward, next_state, q_networks, target_networks):
        states = torch.tensor(state, dtype=torch.float32).to(device)
        actions = torch.tensor(action, dtype=torch.long).to(device)
        rewards = torch.tensor(reward, dtype=torch.float32).to(device)
        next_states = torch.tensor(next_state, dtype=torch.float32).to(device)
        agent_q_values=[]
        target_q_values = []
        for agent_idx in range(len(q_networks)):

            q_vals = q_networks[agent_idx](states[:, agent_idx, :, :, :])
            agent_q_values.append(q_vals.gather(dim=1, index=actions[:, agent_idx].unsqueeze(1)))  # Select Q-value for taken action
            
            next_q_values = target_networks[agent_idx](states[:, agent_idx, :, :, :])
            greedy_actions = next_q_values.argmax( dim=1, keepdim= True)
            target_q_values.append(q_vals.gather(dim=1, index=greedy_actions))
        
        target_q_values = torch.cat(target_q_values, dim=1)
        agent_q_values = torch.cat(agent_q_values, dim=1)  # Shape: (batch_size, n_agents)
        # TD-error: δ = Q(s, a) - target

        td_error = torch.abs(rewards.squeeze(1) + target_q_values - agent_q_values)
        td_error = np.array(td_error.cpu().detach().numpy())
        return td_error
    
    def size(self):
        return len(self.buffer)

# %% [markdown]
# ### Buffer for sequences

# %%
class ReplayBuffer_sequence:
    def __init__(self, buffer_size=10000, sequence_length=5):
        self.buffer = deque(maxlen=buffer_size)
        self.sequence_length = sequence_length

    def add(self, experience):
        self.buffer.append(experience)
        
    def sample(self, batch_size):
        sequences = []
        for _ in range(batch_size):
            start_index = random.randint(0, len(self.buffer) - self.sequence_length)
            sequence = [self.buffer[i] for i in range(start_index, start_index + self.sequence_length)]
            sequences.append(sequence)
        
        # Transpose the sequences to get batches of each component
        
        states = torch.stack([torch.stack([torch.stack(seq[0]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        actions = torch.stack([torch.stack([torch.tensor(seq[1]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        rewards = torch.stack([torch.stack([torch.tensor(seq[2]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        next_states = torch.stack([torch.stack([torch.stack(seq[3]).to(device) for seq in sequence]) for sequence in sequences], dim=0)
        terminations = torch.stack([torch.stack([torch.tensor(seq[4], dtype=torch.int).to(device) for seq in sequence]) for sequence in sequences], dim=2)
        hidden_states = torch.cat([sequence[-1][5] for sequence in sequences], dim = -2).to(device)
        next_hidden_states = torch.cat([sequence[-1][6] for sequence in sequences], dim = -2).to(device)
        
        return (states, actions, rewards, next_states, terminations, hidden_states, next_hidden_states)

    def size(self):
        return len(self.buffer)

# %% [markdown]
# # **Utility functions**

# %% [markdown]
# ## epsilon greedy, update and weights

# %%
# Adjusted epsilon-greedy action function
def epsilon_greedy_action(agent_q_network, state, epsilon, legal_actions, exploring = True):
    
    if random.random() < epsilon and exploring:
        # Explore: take a random action
        action = random.choice(legal_actions)
    else:
        state = state.unsqueeze(0).to(device)  # Add batch dimension
        q_values = agent_q_network(state)
        q_values = q_values.cpu().detach().numpy()
        action = np.random.choice(np.flatnonzero(q_values == q_values.max()))

    return action


def update_target_network(agent_q_networks, target_q_networks):
    for target, source in zip(target_q_networks, agent_q_networks):
        target.load_state_dict(source.state_dict())



def interpolate_weights(start_weights, end_weights, factor):
    return [(1 - factor) * start + factor * end for start, end in zip(start_weights, end_weights)]

def get_dynamic_weights(episode, n_episodes):
    # Define the initial weights for the beginning, middle, and end
    weights_beginning = [1, 0, 0, 0, 0, 0]
    weights_middle = [0, 0.33, 0.34, 0.33, 0, 0]
    weights_end = [0, 0, 0, 0, 0.5, 0.5]

    # Calculate the transition points
    transition1 = n_episodes // 3
    transition2 = 2 * n_episodes // 3

    # Adjust weights based on the current episode
    if episode < transition1:
        factor = episode / transition1
        return interpolate_weights(weights_beginning, weights_middle, factor)
    elif episode < transition2:
        factor = (episode - transition1) / (transition2 - transition1)
        return interpolate_weights(weights_middle, weights_end, factor)
    else:
        factor = (episode - transition2) / (n_episodes - transition2)
        return interpolate_weights(weights_middle, weights_end, factor)
    

import os

def create_folder_if_not_exists(folder_path):
    os.makedirs(folder_path, exist_ok=True)

# %% [markdown]
# ## individual rewards

# %%
## individual reward
from capture import AgentRules
def calculate_individual_reward(env,agentIndex,action, reward, distancer, counter):

    next_state = env.game.state.generateSuccessor(agentIndex, env.action_mapping[action])
    # --- Reward for capturing food ---
    if env.game.state.getAgentState(agentIndex).numCarrying < next_state.getAgentState(agentIndex).numCarrying:
        reward += 1

    # --- Reward for delivering food ---
    if env.game.state.getAgentState(agentIndex).numCarrying > 0 and next_state.getAgentState(agentIndex).numCarrying == 0 and env.game.state.getAgentState(agentIndex).start.pos != next_state.getAgentPosition(agentIndex):
        print('gave food to side')
        reward += (env.game.state.getAgentState(agentIndex).numCarrying)*2

    # --- Maze Distance penalty ---
    start_position = env.game.state.getAgentState(agentIndex).start.pos
    next_position = next_state.getAgentPosition(agentIndex)
    maze_distance = distancer.getDistance(next_position, start_position)

    radius = 10
    if maze_distance <= radius and counter<=0:
        reward -= (radius - maze_distance)*0.001

    #--- legal actions reward ---
    legal_actions = AgentRules.getLegalActions(env.game.state, agentIndex)
    if env.action_mapping[action] in legal_actions:
        reward += 0.05  
    else:
        reward -= 0.05

           
    for red_team_index in [0, 2]:
        if (env.game.state.data.agentStates[red_team_index].isPacman and
                not next_state.data.agentStates[red_team_index].isPacman):
            if next_state.data.agentStates[red_team_index].configuration.pos == next_state.data.agentStates[red_team_index].start.pos:
                print('defended')
                reward += 0.75
    return reward

# %% [markdown]
# # **Section 2: Training loops**

# %% [markdown]
# ## IQL

# %%
import layout
from distanceCalculator import Distancer

def train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p, learn_p, random_enemy=False, schedule=False, later_exploration = False):
    
    optimizer = optim.Adam([param for net in agent_q_networks for param in net.parameters()], lr=learn_p.lr_agent)
    #mixing_optimizer = optim.Adam(mixing_network.parameters(), lr=learn_p.lr_mixing)
    if schedule:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=learn_p.gamma)
        #scheduler_mix = torch.optim.lr.scheduler.ExponentialLR(mixing_optimizer, gamma=learn_p.learn_gamma)
   
    n_episodes = train_p.n_episodes
    batch_size = train_p.batch_size
    gamma = train_p.gamma
    epsilon = train_p.epsilon  # Initial exploration probability
    epsilon_min = train_p.epsilon_min
    epsilon_decay = train_p.epsilon_decay
    target_update_frequency = train_p.target_update_frequency

    l = layout.getLayout('bloxCapture.lay')
    print(l.walls)
    distancer = Distancer(l)
    distancer.getMazeDistances()
    
    legal_actions = [0, 1, 2, 3, 4]
    agent_indexes = [1, 3]
    episode_rewards = []
    win_rates = []
    enemieName = env.enemieName
    if random_enemy:
        enemylist = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']
        weights_enemy = get_dynamic_weights(0, n_episodes)
        enemieName = np.random.choice(enemylist, p=weights_enemy)

    create_folder_if_not_exists(name_experiment)

    for episode in range(n_episodes):
        steps_counter = 0
        print(f"enemy: {enemieName}")
        run_counter =[11,11]

        done = {agent_id: False for agent_id in agent_indexes}
        if random_enemy:
            weights_enemy = get_dynamic_weights(episode, n_episodes)
            enemieName = np.random.choice(enemylist, p=weights_enemy)
        env.reset(enemieName=enemieName)
        blue_player1_reward = 0
        blue_player2_reward = 0
        score = 0
        if later_exploration:
            exploring = False
        else:
            exploring = True
        while not all(done.values()):
            if later_exploration and steps_counter > 10:
                exploring = True
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []

            reward_dist = [0,0]
            for i, agent_index in enumerate(agent_indexes):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                action = epsilon_greedy_action(agent_q_networks[i], state, epsilon, legal_actions, exploring)
                actions[agent_index] = action
                reward_dist[i] = individual_reward(env,agent_index,action,reward_dist[i],distancer,run_counter[i])



            next_states, rewards, terminations, info = env.step(actions)
            for i, index in enumerate(agent_indexes):
                if env.game.state.getAgentState(index).start.pos == env.game.state.getAgentPosition(index):
                    run_counter[i] = 11
                else:
                    run_counter[i] -=1
            
            score -= info["score_change"]
            done = {key: value for key, value in terminations.items() if key in agent_indexes}
            blue_player1_reward += (rewards[1] - reward_dist[0])
            blue_player2_reward += (rewards[3] - reward_dist[1])

            next_states_converted = []
            rewards_converted = []
            terminations_converted = []
            actions_converted = []

            for index in agent_indexes:
                next_states_converted.append(list(next_states.values())[index])
                rewards_converted.append(rewards[index])
                terminations_converted.append(terminations[index])
                actions_converted.append(actions[index])

            next_states_converted = torch.stack(next_states_converted)
            states_converted = torch.stack(states)
            rewards_converted = [rewards_converted]
            terminations_converted = [terminations_converted]
            replay_buffer.add(
                (states_converted, actions_converted, rewards_converted, next_states_converted, terminations_converted))

            if replay_buffer.size() >= batch_size:
                batch = replay_buffer.sample(batch_size)
                loss1, loss2 = compute_td_loss_iql(agent_q_networks, target_q_networks, batch,
                                               gamma=gamma)
                wandb.log({"loss1": loss1})
                wandb.log({"loss2": loss2})

                # Zero gradients for all optimizers
                optimizer.zero_grad()

                # Backpropagate once for all losses
                loss1.backward(retain_graph=True)
                loss2.backward()

                # Update weights
                optimizer.step()
                if schedule:
                    scheduler.step()
                    wandb.log({"lr": optimizer.param_groups[0]['lr']})

            steps_counter += 1
        wandb.log({"epsilon": epsilon})
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        wandb.log({"blue_player1_reward": blue_player1_reward})
        wandb.log({"blue_player2_reward": blue_player2_reward})
        wandb.log({"episode": episode})
        wandb.log({'score': score})




        if (episode + 1) % target_update_frequency == 0:
            update_target_network(agent_q_networks, target_q_networks)
        
        if (episode) % target_update_frequency == 0:
            torch.save(agent_q_networks[0].state_dict(),f'{name_experiment}/agent1_{episode+1}.pth')
            torch.save(agent_q_networks[1].state_dict(),f'{name_experiment}/agent3_{episode+1}.pth')
         # Log rewards and win rates
        episode_rewards.append(blue_player1_reward+blue_player2_reward)
        print(blue_player1_reward)
        print(blue_player2_reward)
        print(f"Episode reward: {blue_player1_reward+blue_player2_reward}")

        if np.sum(env.game.state.getBlueFood().data) == 0:
            win_rates.append(1)
        else:
            win_rates.append(0)

        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(episode_rewards[-10:])
            avg_win_rate = np.mean(win_rates[-10:])
            print(f"Episode {episode + 1}/{n_episodes}, Average Reward: {avg_reward:.2f}, Win Rate: {avg_win_rate:.2f}")

    # Plot rewards and win rates
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(episode_rewards, label="Average Reward")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title("Average Reward per Episode")
    plt.legend()

    plt.subplot(1, 2, 2)
    smoothed_win_rates = np.convolve(win_rates, np.ones(10)/10, mode='valid') if len(win_rates) > 10 else win_rates
    plt.plot(smoothed_win_rates, label="Win Rate (Smoothed)")
    plt.xlabel("Episode")
    plt.ylabel("Win Rate")
    plt.title("Win Rate Over Episodes")
    plt.legend()

    plt.tight_layout()
    plt.show()

    print("Training completed.")

# %% [markdown]
# ## QMIX with everything

# %%
import layout
from distanceCalculator import Distancer

def train_qmix(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p, learn_p, random_enemy=False, schedule=False, later_exploration = False, individual_reward = False):
    
    optimizer = optim.Adam([param for net in agent_q_networks for param in net.parameters()], lr=learn_p.lr_agent)
    mixing_optimizer = optim.Adam(mixing_network.parameters(), lr=learn_p.lr_mix)
    if schedule:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=learn_p.gamma)
        scheduler_mix = torch.optim.lr_scheduler.ExponentialLR(mixing_optimizer, gamma=learn_p.gamma)
   
    n_episodes = train_p.n_episodes
    batch_size = train_p.batch_size
    gamma = train_p.gamma
    epsilon = train_p.epsilon  # Initial exploration probability
    epsilon_min = train_p.epsilon_min
    epsilon_decay = train_p.epsilon_decay
    target_update_frequency = train_p.target_update_frequency

    l = layout.getLayout('bloxCapture.lay') 
    print(l.walls)
    distancer = Distancer(l)
    distancer.getMazeDistances()
    print(f'hallo: {distancer._distances}')
    
    legal_actions = [0, 1, 2, 3, 4]
    agent_indexes = [1, 3]
    episode_rewards = []
    win_rates = []
    enemieName = env.enemieName

    weights = None
    
    if random_enemy:
        enemylist = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']
        weights_enemy = get_dynamic_weights(0, n_episodes)
        enemieName = np.random.choice(enemylist, p=weights_enemy)

    create_folder_if_not_exists(name_experiment)

    for episode in range(n_episodes):
        steps_counter = 0
        run_counter = [11,11]
        print(f"enemy: {enemieName}")

        done = {agent_id: False for agent_id in agent_indexes}
        if random_enemy:
            weights_enemy = get_dynamic_weights(episode, n_episodes)
            enemieName = np.random.choice(enemylist, p=weights_enemy)
        env.reset(enemieName=enemieName)
        blue_player1_reward = 0
        blue_player2_reward = 0
        score = 0
        if later_exploration:
            exploring = False
            start = episode/n_episodes * env.length/2 #slowly go to later exploring after half of the episode at the last episode
        else:
            exploring = True
    
        while not all(done.values()):
            print(f"episode: step:     {episode} : {steps_counter}")
            if later_exploration:
                if steps_counter > start:
                    exploring = True
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []
            if  individual_reward:
                indv_rewards = [0,0]
            for i, agent_index in enumerate(agent_indexes):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                action = epsilon_greedy_action(agent_q_networks[i], state, epsilon, legal_actions, exploring)
                actions[agent_index] = action
                if individual_reward:
                    indv_rewards[i] = calculate_individual_reward(env,agent_index,action,indv_rewards[i],distancer,run_counter[i])

            next_states, rewards, terminations, info = env.step(actions)

            if individual_reward:
                for i, index in enumerate(agent_indexes):
                    if env.game.state.getAgentState(index).start.pos == env.game.state.getAgentPosition(index):
                        run_counter[i] = 11
                    else:
                        run_counter[i] -=1
                    
            score -= info["score_change"]
            done = {key: value for key, value in terminations.items() if key in agent_indexes}
            blue_player1_reward += (rewards[1]+ 0 if not individual_reward else indv_rewards[0] )
            blue_player2_reward += (rewards[3]+ 0 if not individual_reward else indv_rewards[1])

            next_states_converted = []
            rewards_converted = []
            terminations_converted = []
            actions_converted = []

            for index in agent_indexes:
                next_states_converted.append(list(next_states.values())[index])
                rewards_converted.append(rewards[index])
                terminations_converted.append(terminations[index])
                actions_converted.append(actions[index])

            next_states_converted = torch.stack(next_states_converted)
            states_converted = torch.stack(states)
            rewards_converted = [rewards_converted]
            terminations_converted = [terminations_converted]
            replay_buffer.add(
                (states_converted, actions_converted, rewards_converted, next_states_converted, terminations_converted))

            if replay_buffer.size() >= batch_size:
                
                if type(replay_buffer) == MultiAgentPrioritizedReplayBuffer:
                    batch = replay_buffer.sample(batch_size, 0.4, agent_q_networks, target_q_networks)
                    weights = batch[-1]
                    batch = batch[:-1]
                elif type(replay_buffer) == MultiAgentPrioritizedReplayBufferTree:
                    batch = replay_buffer.sample(batch_size, agent_q_networks, target_q_networks)
                    weights = batch[-2]
                    batch = batch[:-2]
                    
                elif type(replay_buffer) == ReplayBuffer:
                    batch = replay_buffer.sample(batch_size)

                loss = compute_td_loss_qmix(agent_q_networks, target_q_networks,mixing_network, batch,
                                               gamma=gamma, weights=weights)
                
                wandb.log({"loss": loss})
                

                # Zero gradients for all optimizers
                optimizer.zero_grad()
                mixing_optimizer.zero_grad()
                # Backpropagate once for all losses
                loss.backward()

                # Update weights
                optimizer.step()
                mixing_optimizer.step()
                

            steps_counter += 1
        if schedule:
            scheduler.step()
            scheduler_mix.step()
            wandb.log({"lr": optimizer.param_groups[0]['lr']})
        wandb.log({"epsilon": epsilon})
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        wandb.log({"blue_player1_reward": blue_player1_reward})
        wandb.log({"blue_player2_reward": blue_player2_reward})
        wandb.log({"episode": episode})
        wandb.log({'score': score})




        if (episode + 1) % target_update_frequency == 0:
            update_target_network(agent_q_networks, target_q_networks)
        
        if (episode + 1) % target_update_frequency == 0:
            torch.save(agent_q_networks[0].state_dict(),f'{name_experiment}/agent1_{episode+1}.pth')
            torch.save(agent_q_networks[1].state_dict(),f'{name_experiment}/agent3_{episode+1}.pth')
         # Log rewards and win rates
        episode_rewards.append(blue_player1_reward+blue_player2_reward)
        print(blue_player1_reward)
        print(blue_player2_reward)
        print(f"Episode reward: {blue_player1_reward+blue_player2_reward}")

        if np.sum(env.game.state.getBlueFood().data) == 0:
            win_rates.append(1)
        else:
            win_rates.append(0)

        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(episode_rewards[-10:])
            avg_win_rate = np.mean(win_rates[-10:])
            print(f"Episode {episode + 1}/{n_episodes}, Average Reward: {avg_reward:.2f}, Win Rate: {avg_win_rate:.2f}")

    # Plot rewards and win rates
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(episode_rewards, label="Average Reward")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title("Average Reward per Episode")
    plt.legend()

    plt.subplot(1, 2, 2)
    smoothed_win_rates = np.convolve(win_rates, np.ones(10)/10, mode='valid') if len(win_rates) > 10 else win_rates
    plt.plot(smoothed_win_rates, label="Win Rate (Smoothed)")
    plt.xlabel("Episode")
    plt.ylabel("Win Rate")
    plt.title("Win Rate Over Episodes")
    plt.legend()

    plt.tight_layout()
    plt.show()

    print("Training completed.")
    return

# %% [markdown]
# ## QMIX with prioritized buffer

# %%
def train_qmix_replay_buffer(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p, learn_p, random_enemy=False, schedule=False, later_exploration = False):
    
    optimizer = optim.Adam([param for net in agent_q_networks for param in net.parameters()], lr=learn_p.lr_agent)
    mixing_optimizer = optim.Adam(mixing_network.parameters(), lr=learn_p.lr_mix)
    if schedule:
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=learn_p.gamma)
        scheduler_mix = torch.optim.lr_scheduler.ExponentialLR(mixing_optimizer, gamma=learn_p.gamma)
   
    n_episodes = train_p.n_episodes
    batch_size = train_p.batch_size
    gamma = train_p.gamma
    epsilon = train_p.epsilon  # Initial exploration probability
    epsilon_min = train_p.epsilon_min
    epsilon_decay = train_p.epsilon_decay
    target_update_frequency = train_p.target_update_frequency
    
    legal_actions = [0, 1, 2, 3, 4]
    agent_indexes = [1, 3]
    episode_rewards = []
    win_rates = []
    enemieName = env.enemieName

    weights = None
    if random_enemy:
        enemylist = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']
        weights_enemy = get_dynamic_weights(0, n_episodes)
        enemieName = np.random.choice(enemylist, p=weights_enemy)

    create_folder_if_not_exists(name_experiment)

    for episode in range(n_episodes):
        steps_counter = 0
        print(f"enemy: {enemieName}")

        done = {agent_id: False for agent_id in agent_indexes}
        if random_enemy:
            weights_enemy = get_dynamic_weights(episode, n_episodes)
            enemieName = np.random.choice(enemylist, p=weights_enemy)
        env.reset(enemieName=enemieName)
        blue_player1_reward = 0
        blue_player2_reward = 0
        score = 0
        if later_exploration:
            exploring = False
        else:
            exploring = True
        while not all(done.values()):
            if later_exploration and steps_counter > 10:
                exploring = True
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []
            for i, agent_index in enumerate(agent_indexes):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                action = epsilon_greedy_action(agent_q_networks[i], state, epsilon, legal_actions, exploring)
                actions[agent_index] = action


            next_states, rewards, terminations, info = env.step(actions)
          
            score -= info["score_change"]
            done = {key: value for key, value in terminations.items() if key in agent_indexes}
            blue_player1_reward += rewards[1]
            blue_player2_reward += rewards[3]

            next_states_converted = []
            rewards_converted = []
            terminations_converted = []
            actions_converted = []

            for index in agent_indexes:
                next_states_converted.append(list(next_states.values())[index])
                rewards_converted.append(rewards[index])
                terminations_converted.append(terminations[index])
                actions_converted.append(actions[index])

            next_states_converted = torch.stack(next_states_converted)
            states_converted = torch.stack(states)
            rewards_converted = [rewards_converted]
            terminations_converted = [terminations_converted]
            replay_buffer.add(
                (states_converted, actions_converted, rewards_converted, next_states_converted, terminations_converted))

            if replay_buffer.size() >= batch_size:
                batch = replay_buffer.sample(batch_size, 0.4, agent_q_networks, target_q_networks)
                weights = batch[-1]
                batch = batch[:-1]
                loss = compute_td_loss_qmix(agent_q_networks, target_q_networks,mixing_network, batch,
                                               gamma=gamma, weights=weights)
                wandb.log({"loss": loss})
                

                # Zero gradients for all optimizers
                optimizer.zero_grad()
                mixing_optimizer.zero_grad()
                # Backpropagate once for all losses
                loss.backward()

                # Update weights
                optimizer.step()
                mixing_optimizer.step()
                if schedule:
                    scheduler.step()
                    scheduler_mix.step()
                    wandb.log({"lr": optimizer.param_groups[0]['lr']})

            steps_counter += 1
        wandb.log({"epsilon": epsilon})
        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        wandb.log({"blue_player1_reward": blue_player1_reward})
        wandb.log({"blue_player2_reward": blue_player2_reward})
        wandb.log({"episode": episode})
        wandb.log({'score': score})




        if (episode + 1) % target_update_frequency == 0:
            update_target_network(agent_q_networks, target_q_networks)
        
        if (episode) % target_update_frequency == 0:
            torch.save(agent_q_networks[0].state_dict(),f'{name_experiment}/agent1_{episode+1}.pth')
            torch.save(agent_q_networks[1].state_dict(),f'{name_experiment}/agent3_{episode+1}.pth')
         # Log rewards and win rates
        episode_rewards.append(blue_player1_reward+blue_player2_reward)
        print(blue_player1_reward)
        print(blue_player2_reward)
        print(f"Episode reward: {blue_player1_reward+blue_player2_reward}")

        if np.sum(env.game.state.getBlueFood().data) == 0:
            win_rates.append(1)
        else:
            win_rates.append(0)

        if (episode + 1) % 10 == 0:
            avg_reward = np.mean(episode_rewards[-10:])
            avg_win_rate = np.mean(win_rates[-10:])
            print(f"Episode {episode + 1}/{n_episodes}, Average Reward: {avg_reward:.2f}, Win Rate: {avg_win_rate:.2f}")

    # Plot rewards and win rates
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(episode_rewards, label="Average Reward")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title("Average Reward per Episode")
    plt.legend()

    plt.subplot(1, 2, 2)
    smoothed_win_rates = np.convolve(win_rates, np.ones(10)/10, mode='valid') if len(win_rates) > 10 else win_rates
    plt.plot(smoothed_win_rates, label="Win Rate (Smoothed)")
    plt.xlabel("Episode")
    plt.ylabel("Win Rate")
    plt.title("Win Rate Over Episodes")
    plt.legend()

    plt.tight_layout()
    plt.show()

    print("Training completed.")

# %%
def train_qmix_LSTM():
    pass

# %%
def train_PPO():
    pass

# %% [markdown]
# # **Section 3: Testing and conclusions**

# %% [markdown]
# ## Testing IQL

# %% [markdown]
# First 300 steps with random enemy on win.lay with fixed lr

# %%
@dataclass
class train_param:
    n_episodes: int = 300
    batch_size: int = 32
    gamma: float = 0.995
    epsilon: float = 0.75
    epsilon_min: float = 0.1
    epsilon_decay: float = 0.995
    target_update_frequency: int = 20

@dataclass
class learn_param:
    lr_mix: float = 0.0001
    lr_agent: float = 0.0001
    gamma: float = 0.99995

#TODO: specific net_param for each network architecture
@dataclass
class net_param_CNN:
    hidden_dim: int = 64
    

train_p_qmix = train_param()
learn_p_qmix = learn_param()
net_p_qmix = net_param_CNN()

# %%
env = gymPacMan_parallel_env(display=True, layout_file="layouts/bloxCapture.lay", length=300, enemieName='randomTeam.py', defenceReward=True)
# Out:
# Loaded layout from file
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts

# %%
n_agents = 2
action_dim = 5

obs_individual_agent = env.get_Observation(0)
obs_shape = obs_individual_agent.shape
global_state = [n_agents]+list(obs_shape)

agent_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p_qmix.hidden_dim).to(device) for _ in range(n_agents)]
target_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p_qmix.hidden_dim).to(device) for _ in range(n_agents)]
mixing_network = SimpleQMixer(n_agents,global_state).to(device)
update_target_network(agent_q_networks, target_q_networks)

replay_buffer = MultiAgentPrioritizedReplayBuffer(buffer_size=1500)

# %%
name_experiment ='SimpleQMIX_CNN_random_blox_basic'
team_name = 'RL_PacMan'
wandb.init(project="", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
train_qmix_replay_buffer(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix)
wandb.finish()
# Out:
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1438679716.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
# (32,)
# (32,)
# 32
# (33,)
# (33,)
# 33
# (34,)
# (34,)
# 34
# (35,)
# (35,)
# 35
# (36,)
# (36,)
# 36
# (37,)
# (37,)
# 37
# (38,)
# (38,)
# 38
# (39,)
# (39,)
# 39
# (40,)
# (40,)
# 40
# (41,)
# (41,)
# 41
# (42,)
# (42,)
# 42
# (43,)
# (43,)
# 43
# (44,)
# (44,)
# 44
# (45,)
# (45,)
# 45
# (46,)
# (46,)
# 46
# (47,)
# (47,)
# 47
# (48,)
# (48,)
# 48
# (49,)
# (49,)
# 49
# (50,)
# (50,)
# 50
# (51,)
# (51,)
# 51
# (52,)
# (52,)
# 52
# (53,)
# (53,)
# 53
# (54,)
# (54,)
# 54
# (55,)
# (55,)
# 55
# (56,)
# (56,)
# 56
# (57,)
# (57,)
# 57
# (58,)
# (58,)
# 58
# (59,)
# (59,)
# 59
# (60,)
# (60,)
# 60
# (61,)
# (61,)
# 61
# (62,)
# (62,)
# 62
# (63,)
# (63,)
# 63
# (64,)
# (64,)
# 64
# (65,)
# (65,)
# 65
# (66,)
# (66,)
# 66
# (67,)
# (67,)
# 67
# (68,)
# (68,)
# 68
# (69,)
# (69,)
# 69
# (70,)
# (70,)
# 70
# (71,)
# (71,)
# 71
# (72,)
# (72,)
# 72
# (73,)
# (73,)
# 73
# (74,)
# (74,)
# 74
# (75,)
# (75,)
# 75
# (76,)
# (76,)
# 76
# (77,)
# (77,)
# 77
# (78,)
# (78,)
# 78
# (79,)
# (79,)
# 79
# (80,)
# (80,)
# 80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[147], line 4
#       2 team_name = 'RL_PacMan'
#       3 wandb.init(project="", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
# ----> 4 train_qmix_replay_buffer(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix)
#       5 wandb.finish()
#
# Cell In[141], line 89, in train_qmix_replay_buffer(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p, learn_p, random_enemy, schedule, later_exploration)
#      87 weights = batch[-1]
#      88 batch = batch[:-1]
# ---> 89 loss = compute_td_loss_qmix(agent_q_networks, target_q_networks,mixing_network, batch,
#      90                                gamma=gamma, weights=weights)
#      91 wandb.log({"loss": loss})
#      94 # Zero gradients for all optimizers
#
# Cell In[131], line 14, in compute_td_loss_qmix(agent_q_networks, target_q_networks, mixing_network, batch, weights, gamma, lambda_)
#      12 agent_qs = []
#      13 for i, agent_q_network in enumerate(agent_q_networks):
# ---> 14     agent_q = agent_q_network(states[:, i, :, :, :])  # Shape: (batch_size, num_actions)
#      15     agent_q = agent_q.gather(dim=1, index=actions[:,i].unsqueeze(1))  # Select action Q-values
#      16     agent_qs.append(agent_q)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[2], line 18, in AgentQNetwork.forward(self, obs)
#      16 x = self.global_pool(x)
#      17 x = torch.flatten(x, start_dim=1)
# ---> 18 x = torch.relu(self.fc1(x))
#      19 q_values = self.fc2(x)
#      20 return q_values
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\fx\traceback.py:72, in format_stack()
#      69     return [current_meta.get("stack_trace", "")]
#      70 else:
#      71     # fallback to traceback.format_stack()
# ---> 72     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:232, in extract_stack(f, limit)
#     230 if f is None:
#     231     f = sys._getframe().f_back
# --> 232 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     233 stack.reverse()
#     234 return stack
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:395, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     392     for f, lineno in frame_gen:
#     393         yield f, (lineno, None, None, None)
# --> 395 return klass._extract_from_extended_frame_gen(
#     396     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     397     capture_locals=capture_locals)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:434, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     430     result.append(FrameSummary(
#     431         filename, lineno, name, lookup_line=False, locals=f_locals,
#     432         end_lineno=end_lineno, colno=colno, end_colno=end_colno))
#     433 for filename in fnames:
# --> 434     linecache.checkcache(filename)
#     435 # If immediate lookup was desired, trigger lookups now.
#     436 if lookup_lines:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except (OSError, ValueError):
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
@dataclass
class train_param:
    n_episodes: int = 100
    batch_size: int = 32
    gamma: float = 0.995
    epsilon: float = 0.3
    epsilon_min: float = 0.1
    epsilon_decay: float = 0.995
    target_update_frequency: int = 20

@dataclass
class learn_param:
    lr_mix: float = 0.0001
    lr_agent: float = 0.0001
    gamma: float = 0.99995

#TODO: specific net_param for each network architecture
@dataclass
class net_param_CNN:
    hidden_dim: int = 64
    

train_p_qmix = train_param()
learn_p_qmix = learn_param()
net_p_qmix = net_param_CNN()

# %%
env = gymPacMan_parallel_env(display=True, layout_file="layouts/bloxCapture.lay", length=300, enemieName='baselineTeam.py', defenceReward=True)
name_experiment ='SimpleQMIX_CNN_random_blox_basic'
team_name = 'RL_PacMan'
wandb.init(entity = team_name, id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
train_qmix_indv_reward(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix)
wandb.finish()

# %% [markdown]
# IQL on tiny with random enemy with scheduled learning_rate

# %%
replay_buffer = ReplayBuffer()
name_experiment ='IQL_CNN_tiny'
team_name = 'RL_PacMan'

env = gymPacMan_parallel_env(display=True, layout_file="layouts/tinyCapture.lay", length=300, enemieName='randomTeam.py', defenceReward=True)
wandb.init(entity = team_name, project="PacManCapture", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")

train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p_iql, learn_p_iql)
wandb.finish()
# Out:
# Loaded layout from file
# Loading Team: /home/seppe/RL/RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 8
#       5 env = gymPacMan_parallel_env(display=True, layout_file="layouts/bloxCapture.lay", length=300, enemieName='randomTeam.py', defenceReward=True)
#       6 wandb.init(entity = team_name, project="PacManCapture", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
# ----> 8 train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p_iql, learn_p_iql)
#       9 wandb.finish()
#
# Cell In[22], line 23, in train_iql(env, name_experiment, agent_q_networks, target_q_networks, replay_buffer, train_p, learn_p, random_enemy, schedule, later_exploration)
#      21 l = layout.getLayout('/layouts/bloxCapture.lay')
#      22 distancer = Distancer(l)
# ---> 23 distancer.getMazeDistances()
#      25 legal_actions = [0, 1, 2, 3, 4]
#      26 agent_indexes = [1, 3]
#
# File ~/RL/RL_MARL_QMIX/distanceCalculator.py:36, in Distancer.getMazeDistances(self)
#      35 def getMazeDistances(self):
# ---> 36   self.dc.run()
#
# File ~/RL/RL_MARL_QMIX/distanceCalculator.py:103, in DistanceCalculator.run(self)
#     100 global distanceMap
#     101 distanceMap = {}
# --> 103 if self.layout.walls not in distanceMap:
#     104   distances = computeDistances(self.layout)
#     105   distanceMap[self.layout.walls] = distances
#
# AttributeError: 'NoneType' object has no attribute 'walls'

# %%
wandb.finish()

# %%
import pandas as pd

# Define the list of enemies
enemies = ['randomTeam.py', 'baselineTeam.py', 'heuristicTeam.py', 'approxQTeam.py', 'MCTSTeam.py', 'AstarTeam.py']

# Initialize results dictionary
results = {enemy: {'wins': 0, 'losses': 0, 'draws': 0} for enemy in enemies}

# Number of games to play against each enemy
num_games = 10

# Function to evaluate the agent against an enemy
def evaluate_agent(env, enemy_name, num_games):
    wins, losses, draws = 0, 0, 0
    for _ in range(num_games):
        env.reset(enemieName=enemy_name)
        done = False
        while not done:
            actions = [-1 for _, _ in enumerate(env.agents)]
            states = []
            for i, agent_index in enumerate([1,3]):
                obs_agent = env.get_Observation(agent_index)
                state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
                states.append(state)
                state = state.unsqueeze(0).to(device)  # Add batch dimension
                q_values = agent_q_networks[i](state)
                q_values = q_values.cpu().detach().numpy()
                action = np.random.choice(np.flatnonzero(q_values == q_values.max()))
                actions[agent_index] = action
            next_state, reward, done, info = env.step(actions)
            if done:
                if info['result'] == 'win':
                    wins += 1
                elif info['result'] == 'loss':
                    losses += 1
                else:
                    draws += 1
    return wins, losses, draws

# Evaluate the agent against each enemy
for enemy in enemies:
    env = gymPacMan_parallel_env(display=False, layout_file="layouts/smallCapture.lay", length=200, enemieName=enemy, defenceReward=True)
    wins, losses, draws = evaluate_agent(env, enemy, num_games)
    results[enemy]['wins'] = wins
    results[enemy]['losses'] = losses
    results[enemy]['draws'] = draws

# Convert results to a DataFrame for better display
results_df = pd.DataFrame(results).T
print(results_df)

# %% [markdown]
# **Testing idea's**
#
# - experience buffer
# - only exploration after first 10 steps
# -

# %% [markdown]
# # Testing everything together

# %%
@dataclass
class train_param:
    n_episodes: int = 300
    batch_size: int = 32
    gamma: float = 0.995
    epsilon: float = 0.75
    epsilon_min: float = 0.2
    epsilon_decay: float = 0.999
    target_update_frequency: int = 20

@dataclass
class learn_param:
    lr_mix: float = 0.0001
    lr_agent: float = 0.0001
    gamma: float = 0.995

#TODO: specific net_param for each network architecture
@dataclass
class net_param_CNN:
    hidden_dim: int = 64
    

train_p_qmix = train_param()
learn_p_qmix = learn_param()
net_p_qmix = net_param_CNN()

# %%
env = gymPacMan_parallel_env(display=False, layout_file="layouts/bloxCapture.lay", length=300, enemieName='randomTeam.py', defenceReward=True)
# Out:
# Loaded layout from file
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts

# %%
gammas = [0.95, 0.99, 0.995]
lrs = [0.0001, 0.0005, 0.001]
hidden_dims = [64, 128]
target_update_frequencies = [10, 20, 30]

# %%
n_agents = 2
action_dim = 5

obs_individual_agent = env.get_Observation(0)
obs_shape = obs_individual_agent.shape
global_state = [n_agents]+list(obs_shape)

# %%
wandb.finish()
# Out:
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>█▅▇▇▄▃▂▂▃▃▂▂▁▁▂▁▁▁▁▁▁▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>9e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224123</strong> at: <a href='https://wandb.ai/RL_PacMan/PacManCapture/runs/SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224123' target="_blank">https://wandb.ai/RL_PacMan/PacManCapture/runs/SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224123</a><br/> View project at: <a href='https://wandb.ai/RL_PacMan/PacManCapture' target="_blank">https://wandb.ai/RL_PacMan/PacManCapture</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20241213_224123-SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224123\logs</code>

# %%
import cProfile
import pstats
from io import StringIO

for gamma in gammas:
    for lr in lrs:
        for hidden_dim in hidden_dims:
            for target_update_frequency in target_update_frequencies:
                train_p_qmix = train_param()
                learn_p_qmix = learn_param()
                net_p_qmix = net_param_CNN()
                train_p_qmix.gamma = gamma
                learn_p_qmix.lr_mix = lr
                learn_p_qmix.lr_agent = lr
                net_p_qmix.hidden_dim = hidden_dim
                train_p_qmix.target_update_frequency = target_update_frequency

                agent_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p_qmix.hidden_dim).to(device) for _ in range(n_agents)]
                target_q_networks = [AgentQNetwork(obs_shape, action_dim, hidden_dim=net_p_qmix.hidden_dim).to(device) for _ in range(n_agents)]
                mixing_network = SimpleQMixer(n_agents,global_state).to(device)
                update_target_network(agent_q_networks, target_q_networks)

                replay_buffer = MultiAgentPrioritizedReplayBufferTree(buffer_size=1500)

                name_experiment = f'SimpleQMIX_everything_random_blox_gamma{gamma}_lr{lr}_hidden{hidden_dim}_target{target_update_frequency}'
                team_name = 'RL_PacMan'
                wandb.init(entity = team_name, project="PacManCapture", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
                
                #pr = cProfile.Profile()
                #pr.enable()
                train_qmix(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix, later_exploration=True, individual_reward=True)
                #pr.disable()
                wandb.finish()
                #s = StringIO()
                #sortby = 'tottime'
                #ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
                #ps.print_stats()
                #print(s.getvalue())


                name_experiment = f'SimpleQMIX_everything_varying_blox_gamma{gamma}_lr{lr}_hidden{hidden_dim}_target{target_update_frequency}'
                train_p_qmix.epsilon = 0.5
                wandb.init(entity = team_name, project="PacManCapture", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
                train_qmix(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix, random_enemy=True, schedule=True, later_exploration=True, individual_reward=True)
                wandb.finish()
# Out:
# Tracking run with wandb version 0.19.0
# Run data is saved locally in <code>c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\wandb\run-20241213_224152-SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224152</code>
# Syncing run <strong><a href='https://wandb.ai/RL_PacMan/PacManCapture/runs/SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224152' target="_blank">SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224152</a></strong> to <a href='https://wandb.ai/RL_PacMan/PacManCapture' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/RL_PacMan/PacManCapture' target="_blank">https://wandb.ai/RL_PacMan/PacManCapture</a>
#  View run at <a href='https://wandb.ai/RL_PacMan/PacManCapture/runs/SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224152' target="_blank">https://wandb.ai/RL_PacMan/PacManCapture/runs/SimpleQMIX_everything_random_blox_gamma0.95_lr0.0001_hidden64_target10__20241213_224152</a>
# TTTTTTTTTTTTTTTTTTTT
# TFTTTTTTTTTTTTTTTTFT
# TFTFFFFFTFFTFFFFFTFT
# TFTFFFFFFFFFFFFFFTFT
# TFTFTFFTTTTTTFFTFTFT
# TFTFTFFFFFFFFFFTFTFT
# TFTFTFFTTTTTTFFTFTFT
# TFTFTFFFFFFFFFFTFTFT
# TFFFFFTFTTTTFTFFFFFT
# TTTTFFTFTTTTFTFFTTTT
# TTTTFFTFTTTTFTFFTTTT
# TFFFFFTFTTTTFTFFFFFT
# TFTFTFFFFFFFFFFTFTFT
# TFTFTFTTTTTTTTFTFTFT
# TFTFTFTFTFFTFTFTFTFT
# TFTFFFFFFFFFFFFFFTFT
# TFTFTTFTTFFTTFTTFTFT
# TFTFTTFTTFFTTFTTFTFT
# TFTFFFFFFFFFFFFFFTFT
# TTTTTTTTTTTTTTTTTTTT
# hallo: {((1, 1), (1, 1)): 0, ((1, 2), (1, 1)): 1, ((1, 3), (1, 1)): 2, ((1, 4), (1, 1)): 3, ((1, 5), (1, 1)): 4, ((1, 6), (1, 1)): 5, ((1, 7), (1, 1)): 6, ((1, 8), (1, 1)): 7, ((1, 11), (1, 1)): 16, ((1, 12), (1, 1)): 17, ((1, 13), (1, 1)): 18, ((1, 14), (1, 1)): 19, ((1, 15), (1, 1)): 20, ((1, 16), (1, 1)): 21, ((1, 17), (1, 1)): 22, ((1, 18), (1, 1)): 23, ((2, 8), (1, 1)): 8, ((2, 11), (1, 1)): 15, ((3, 1), (1, 1)): 16, ((3, 2), (1, 1)): 15, ((3, 3), (1, 1)): 14, ((3, 4), (1, 1)): 13, ((3, 5), (1, 1)): 12, ((3, 6), (1, 1)): 11, ((3, 7), (1, 1)): 10, ((3, 8), (1, 1)): 9, ((3, 11), (1, 1)): 14, ((3, 12), (1, 1)): 15, ((3, 13), (1, 1)): 16, ((3, 14), (1, 1)): 17, ((3, 15), (1, 1)): 18, ((3, 16), (1, 1)): 19, ((3, 17), (1, 1)): 20, ((4, 1), (1, 1)): 17, ((4, 4), (1, 1)): 14, ((4, 8), (1, 1)): 10, ((4, 9), (1, 1)): 11, ((4, 10), (1, 1)): 12, ((4, 11), (1, 1)): 13, ((4, 16), (1, 1)): 20, ((4, 17), (1, 1)): 21, ((5, 1), (1, 1)): 18, ((5, 4), (1, 1)): 15, ((5, 5), (1, 1)): 14, ((5, 6), (1, 1)): 13, ((5, 7), (1, 1)): 12, ((5, 8), (1, 1)): 11, ((5, 9), (1, 1)): 12, ((5, 10), (1, 1)): 13, ((5, 11), (1, 1)): 14, ((5, 12), (1, 1)): 15, ((5, 13), (1, 1)): 16, ((5, 14), (1, 1)): 17, ((5, 15), (1, 1)): 18, ((5, 16), (1, 1)): 19, ((5, 17), (1, 1)): 20, ((6, 1), (1, 1)): 19, ((6, 2), (1, 1)): 18, ((6, 3), (1, 1)): 17, ((6, 4), (1, 1)): 16, ((6, 7), (1, 1)): 13, ((6, 12), (1, 1)): 16, ((6, 13), (1, 1)): 17, ((6, 14), (1, 1)): 18, ((6, 15), (1, 1)): 19, ((6, 16), (1, 1)): 20, ((6, 17), (1, 1)): 21, ((7, 1), (1, 1)): 20, ((7, 4), (1, 1)): 17, ((7, 5), (1, 1)): 18, ((7, 7), (1, 1)): 14, ((7, 8), (1, 1)): 15, ((7, 9), (1, 1)): 16, ((7, 10), (1, 1)): 17, ((7, 11), (1, 1)): 18, ((7, 12), (1, 1)): 17, ((7, 14), (1, 1)): 19, ((7, 16), (1, 1)): 21, ((7, 17), (1, 1)): 22, ((8, 1), (1, 1)): 21, ((8, 4), (1, 1)): 18, ((8, 7), (1, 1)): 15, ((8, 12), (1, 1)): 18, ((8, 14), (1, 1)): 20, ((8, 16), (1, 1)): 22, ((9, 1), (1, 1)): 22, ((9, 2), (1, 1)): 21, ((9, 3), (1, 1)): 20, ((9, 4), (1, 1)): 19, ((9, 5), (1, 1)): 20, ((9, 7), (1, 1)): 16, ((9, 12), (1, 1)): 19, ((9, 14), (1, 1)): 21, ((9, 16), (1, 1)): 23, ((9, 17), (1, 1)): 24, ((10, 1), (1, 1)): 23, ((10, 2), (1, 1)): 22, ((10, 3), (1, 1)): 21, ((10, 4), (1, 1)): 20, ((10, 5), (1, 1)): 21, ((10, 7), (1, 1)): 17, ((10, 12), (1, 1)): 20, ((10, 14), (1, 1)): 22, ((10, 16), (1, 1)): 24, ((10, 17), (1, 1)): 25, ((11, 1), (1, 1)): 24, ((11, 4), (1, 1)): 21, ((11, 7), (1, 1)): 18, ((11, 12), (1, 1)): 21, ((11, 14), (1, 1)): 23, ((11, 16), (1, 1)): 25, ((12, 1), (1, 1)): 25, ((12, 4), (1, 1)): 22, ((12, 5), (1, 1)): 23, ((12, 7), (1, 1)): 19, ((12, 8), (1, 1)): 20, ((12, 9), (1, 1)): 21, ((12, 10), (1, 1)): 22, ((12, 11), (1, 1)): 23, ((12, 12), (1, 1)): 22, ((12, 14), (1, 1)): 24, ((12, 16), (1, 1)): 26, ((12, 17), (1, 1)): 27, ((13, 1), (1, 1)): 26, ((13, 2), (1, 1)): 25, ((13, 3), (1, 1)): 24, ((13, 4), (1, 1)): 23, ((13, 7), (1, 1)): 20, ((13, 12), (1, 1)): 23, ((13, 13), (1, 1)): 24, ((13, 14), (1, 1)): 25, ((13, 15), (1, 1)): 26, ((13, 16), (1, 1)): 27, ((13, 17), (1, 1)): 28, ((14, 1), (1, 1)): 27, ((14, 4), (1, 1)): 24, ((14, 5), (1, 1)): 23, ((14, 6), (1, 1)): 22, ((14, 7), (1, 1)): 21, ((14, 8), (1, 1)): 22, ((14, 9), (1, 1)): 23, ((14, 10), (1, 1)): 24, ((14, 11), (1, 1)): 25, ((14, 12), (1, 1)): 24, ((14, 13), (1, 1)): 25, ((14, 14), (1, 1)): 26, ((14, 15), (1, 1)): 27, ((14, 16), (1, 1)): 28, ((14, 17), (1, 1)): 29, ((15, 1), (1, 1)): 28, ((15, 4), (1, 1)): 25, ((15, 8), (1, 1)): 23, ((15, 9), (1, 1)): 24, ((15, 10), (1, 1)): 25, ((15, 11), (1, 1)): 26, ((15, 16), (1, 1)): 29, ((15, 17), (1, 1)): 30, ((16, 1), (1, 1)): 29, ((16, 2), (1, 1)): 28, ((16, 3), (1, 1)): 27, ((16, 4), (1, 1)): 26, ((16, 5), (1, 1)): 27, ((16, 6), (1, 1)): 26, ((16, 7), (1, 1)): 25, ((16, 8), (1, 1)): 24, ((16, 11), (1, 1)): 27, ((16, 12), (1, 1)): 28, ((16, 13), (1, 1)): 29, ((16, 14), (1, 1)): 30, ((16, 15), (1, 1)): 31, ((16, 16), (1, 1)): 30, ((16, 17), (1, 1)): 31, ((17, 8), (1, 1)): 25, ((17, 11), (1, 1)): 28, ((18, 1), ...
# episode: 0
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# steps: 0
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\3420583656.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   state = torch.tensor(obs_agent, dtype=torch.float32).to(device)
# steps: 1
# steps: 2
# steps: 3
# steps: 4
# steps: 5
# steps: 6
# steps: 7
# steps: 8
# steps: 9
# steps: 10
# steps: 11
# steps: 12
# steps: 13
# steps: 14
# steps: 15
# steps: 16
# steps: 17
# steps: 18
# steps: 19
# steps: 20
# steps: 21
# steps: 22
# steps: 23
# steps: 24
# steps: 25
# steps: 26
# steps: 27
# steps: 28
# steps: 29
# steps: 30
# steps: 31
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   states = torch.tensor(states, dtype=torch.float32).to(device)
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   actions = torch.tensor(actions, dtype=torch.long).to(device)
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   next_states = torch.tensor(next_states, dtype=torch.float32).to(device)
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dones = torch.tensor(dones, dtype=torch.float32).to(device)
# C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1630895436.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weights = torch.tensor(weights, dtype=torch.float32).to(device)
# weights:   torch.Size([32, 1])
# steps: 32
# weights:   torch.Size([32, 1])
# steps: 33
# weights:   torch.Size([32, 1])
# steps: 34
# weights:   torch.Size([32, 1])
# steps: 35
# weights:   torch.Size([32, 1])
# steps: 36
# weights:   torch.Size([32, 1])
# steps: 37
# weights:   torch.Size([32, 1])
# steps: 38
# weights:   torch.Size([32, 1])
# steps: 39
# weights:   torch.Size([32, 1])
# steps: 40
# weights:   torch.Size([32, 1])
# steps: 41
# weights:   torch.Size([32, 1])
# steps: 42
# weights:   torch.Size([32, 1])
# steps: 43
# weights:   torch.Size([32, 1])
# steps: 44
# weights:   torch.Size([32, 1])
# steps: 45
# weights:   torch.Size([32, 1])
# steps: 46
# weights:   torch.Size([32, 1])
# steps: 47
# weights:   torch.Size([32, 1])
# steps: 48
# weights:   torch.Size([32, 1])
# steps: 49
# weights:   torch.Size([32, 1])
# steps: 50
# weights:   torch.Size([32, 1])
# steps: 51
# weights:   torch.Size([32, 1])
# steps: 52
# weights:   torch.Size([32, 1])
# steps: 53
# weights:   torch.Size([32, 1])
# steps: 54
# weights:   torch.Size([32, 1])
# steps: 55
# weights:   torch.Size([32, 1])
# steps: 56
# weights:   torch.Size([32, 1])
# steps: 57
# weights:   torch.Size([32, 1])
# steps: 58
# weights:   torch.Size([32, 1])
# steps: 59
# weights:   torch.Size([32, 1])
# steps: 60
# weights:   torch.Size([32, 1])
# steps: 61
# weights:   torch.Size([32, 1])
# steps: 62
# weights:   torch.Size([32, 1])
# steps: 63
# weights:   torch.Size([32, 1])
# steps: 64
# weights:   torch.Size([32, 1])
# steps: 65
# weights:   torch.Size([32, 1])
# steps: 66
# weights:   torch.Size([32, 1])
# steps: 67
# weights:   torch.Size([32, 1])
# steps: 68
# weights:   torch.Size([32, 1])
# steps: 69
# weights:   torch.Size([32, 1])
# steps: 70
# weights:   torch.Size([32, 1])
# steps: 71
# weights:   torch.Size([32, 1])
# steps: 72
# weights:   torch.Size([32, 1])
# steps: 73
# weights:   torch.Size([32, 1])
# steps: 74
# weights:   torch.Size([32, 1])
# steps: 75
# weights:   torch.Size([32, 1])
# steps: 76
# weights:   torch.Size([32, 1])
# steps: 77
# weights:   torch.Size([32, 1])
# steps: 78
# weights:   torch.Size([32, 1])
# steps: 79
# weights:   torch.Size([32, 1])
# steps: 80
# weights:   torch.Size([32, 1])
# steps: 81
# weights:   torch.Size([32, 1])
# steps: 82
# weights:   torch.Size([32, 1])
# steps: 83
# weights:   torch.Size([32, 1])
# steps: 84
# weights:   torch.Size([32, 1])
# steps: 85
# weights:   torch.Size([32, 1])
# steps: 86
# weights:   torch.Size([32, 1])
# steps: 87
# weights:   torch.Size([32, 1])
# steps: 88
# weights:   torch.Size([32, 1])
# steps: 89
# weights:   torch.Size([32, 1])
# steps: 90
# weights:   torch.Size([32, 1])
# steps: 91
# weights:   torch.Size([32, 1])
# steps: 92
# weights:   torch.Size([32, 1])
# steps: 93
# weights:   torch.Size([32, 1])
# steps: 94
# weights:   torch.Size([32, 1])
# steps: 95
# weights:   torch.Size([32, 1])
# steps: 96
# weights:   torch.Size([32, 1])
# steps: 97
# weights:   torch.Size([32, 1])
# steps: 98
# weights:   torch.Size([32, 1])
# steps: 99
# weights:   torch.Size([32, 1])
# steps: 100
# weights:   torch.Size([32, 1])
# steps: 101
# weights:   torch.Size([32, 1])
# steps: 102
# weights:   torch.Size([32, 1])
# steps: 103
# weights:   torch.Size([32, 1])
# steps: 104
# weights:   torch.Size([32, 1])
# steps: 105
# weights:   torch.Size([32, 1])
# steps: 106
# weights:   torch.Size([32, 1])
# steps: 107
# weights:   torch.Size([32, 1])
# steps: 108
# weights:   torch.Size([32, 1])
# steps: 109
# weights:   torch.Size([32, 1])
# steps: 110
# weights:   torch.Size([32, 1])
# steps: 111
# weights:   torch.Size([32, 1])
# steps: 112
# weights:   torch.Size([32, 1])
# steps: 113
# weights:   torch.Size([32, 1])
# steps: 114
# weights:   torch.Size([32, 1])
# steps: 115
# weights:   torch.Size([32, 1])
# steps: 116
# weights:   torch.Size([32, 1])
# steps: 117
# weights:   torch.Size([32, 1])
# steps: 118
# weights:   torch.Size([32, 1])
# steps: 119
# weights:   torch.Size([32, 1])
# steps: 120
# weights:   torch.Size([32, 1])
# steps: 121
# weights:   torch.Size([32, 1])
# steps: 122
# weights:   torch.Size([32, 1])
# steps: 123
# weights:   torch.Size([32, 1])
# steps: 124
# weights:   torch.Size([32, 1])
# steps: 125
# weights:   torch.Size([32, 1])
# steps: 126
# weights:   torch.Size([32, 1])
# steps: 127
# weights:   torch.Size([32, 1])
# steps: 128
# weights:   torch.Size([32, 1])
# steps: 129
# weights:   torch.Size([32, 1])
# steps: 130
# weights:   torch.Size([32, 1])
# steps: 131
# weights:   torch.Size([32, 1])
# steps: 132
# weights:   torch.Size([32, 1])
# steps: 133
# weights:   torch.Size([32, 1])
# steps: 134
# weights:   torch.Size([32, 1])
# steps: 135
# weights:   torch.Size([32, 1])
# steps: 136
# weights:   torch.Size([32, 1])
# steps: 137
# weights:   torch.Size([32, 1])
# steps: 138
# weights:   torch.Size([32, 1])
# steps: 139
# weights:   torch.Size([32, 1])
# steps: 140
# weights:   torch.Size([32, 1])
# steps: 141
# weights:   torch.Size([32, 1])
# steps: 142
# weights:   torch.Size([32, 1])
# steps: 143
# weights:   torch.Size([32, 1])
# steps: 144
# weights:   torch.Size([32, 1])
# steps: 145
# weights:   torch.Size([32, 1])
# steps: 146
# weights:   torch.Size([32, 1])
# steps: 147
# weights:   torch.Size([32, 1])
# steps: 148
# weights:   torch.Size([32, 1])
# steps: 149
# weights:   torch.Size([32, 1])
# steps: 150
# weights:   torch.Size([32, 1])
# steps: 151
# weights:   torch.Size([32, 1])
# steps: 152
# weights:   torch.Size([32, 1])
# steps: 153
# weights:   torch.Size([32, 1])
# steps: 154
# weights:   torch.Size([32, 1])
# steps: 155
# weights:   torch.Size([32, 1])
# steps: 156
# weights:   torch.Size([32, 1])
# steps: 157
# weights:   torch.Size([32, 1])
# steps: 158
# weights:   torch.Size([32, 1])
# steps: 159
# weights:   torch.Size([32, 1])
# steps: 160
# weights:   torch.Size([32, 1])
# steps: 161
# weights:   torch.Size([32, 1])
# steps: 162
# weights:   torch.Size([32, 1])
# steps: 163
# weights:   torch.Size([32, 1])
# steps: 164
# weights:   torch.Size([32, 1])
# steps: 165
# weights:   torch.Size([32, 1])
# steps: 166
# weights:   torch.Size([32, 1])
# steps: 167
# weights:   torch.Size([32, 1])
# steps: 168
# weights:   torch.Size([32, 1])
# steps: 169
# weights:   torch.Size([32, 1])
# steps: 170
# weights:   torch.Size([32, 1])
# steps: 171
# weights:   torch.Size([32, 1])
# steps: 172
# weights:   torch.Size([32, 1])
# steps: 173
# weights:   torch.Size([32, 1])
# steps: 174
# weights:   torch.Size([32, 1])
# steps: 175
# weights:   torch.Size([32, 1])
# steps: 176
# weights:   torch.Size([32, 1])
# steps: 177
# weights:   torch.Size([32, 1])
# steps: 178
# weights:   torch.Size([32, 1])
# steps: 179
# weights:   torch.Size([32, 1])
# steps: 180
# weights:   torch.Size([32, 1])
# steps: 181
# weights:   torch.Size([32, 1])
# steps: 182
# weights:   torch.Size([32, 1])
# steps: 183
# weights:   torch.Size([32, 1])
# steps: 184
# weights:   torch.Size([32, 1])
# steps: 185
# weights:   torch.Size([32, 1])
# steps: 186
# weights:   torch.Size([32, 1])
# steps: 187
# weights:   torch.Size([32, 1])
# steps: 188
# weights:   torch.Size([32, 1])
# steps: 189
# weights:   torch.Size([32, 1])
# steps: 190
# weights:   torch.Size([32, 1])
# steps: 191
# weights:   torch.Size([32, 1])
# steps: 192
# weights:   torch.Size([32, 1])
# steps: 193
# weights:   torch.Size([32, 1])
# steps: 194
# weights:   torch.Size([32, 1])
# steps: 195
# weights:   torch.Size([32, 1])
# steps: 196
# weights:   torch.Size([32, 1])
# steps: 197
# weights:   torch.Size([32, 1])
# steps: 198
# weights:   torch.Size([32, 1])
# steps: 199
# weights:   torch.Size([32, 1])
# steps: 200
# weights:   torch.Size([32, 1])
# steps: 201
# weights:   torch.Size([32, 1])
# steps: 202
# weights:   torch.Size([32, 1])
# steps: 203
# weights:   torch.Size([32, 1])
# steps: 204
# weights:   torch.Size([32, 1])
# steps: 205
# weights:   torch.Size([32, 1])
# steps: 206
# weights:   torch.Size([32, 1])
# steps: 207
# weights:   torch.Size([32, 1])
# steps: 208
# weights:   torch.Size([32, 1])
# steps: 209
# weights:   torch.Size([32, 1])
# steps: 210
# weights:   torch.Size([32, 1])
# steps: 211
# weights:   torch.Size([32, 1])
# steps: 212
# weights:   torch.Size([32, 1])
# steps: 213
# weights:   torch.Size([32, 1])
# steps: 214
# weights:   torch.Size([32, 1])
# steps: 215
# weights:   torch.Size([32, 1])
# steps: 216
# weights:   torch.Size([32, 1])
# steps: 217
# weights:   torch.Size([32, 1])
# steps: 218
# weights:   torch.Size([32, 1])
# steps: 219
# weights:   torch.Size([32, 1])
# steps: 220
# weights:   torch.Size([32, 1])
# steps: 221
# weights:   torch.Size([32, 1])
# steps: 222
# weights:   torch.Size([32, 1])
# steps: 223
# weights:   torch.Size([32, 1])
# steps: 224
# weights:   torch.Size([32, 1])
# steps: 225
# weights:   torch.Size([32, 1])
# steps: 226
# weights:   torch.Size([32, 1])
# steps: 227
# weights:   torch.Size([32, 1])
# steps: 228
# weights:   torch.Size([32, 1])
# steps: 229
# weights:   torch.Size([32, 1])
# steps: 230
# weights:   torch.Size([32, 1])
# steps: 231
# weights:   torch.Size([32, 1])
# steps: 232
# weights:   torch.Size([32, 1])
# steps: 233
# weights:   torch.Size([32, 1])
# steps: 234
# weights:   torch.Size([32, 1])
# steps: 235
# weights:   torch.Size([32, 1])
# steps: 236
# weights:   torch.Size([32, 1])
# steps: 237
# weights:   torch.Size([32, 1])
# steps: 238
# weights:   torch.Size([32, 1])
# steps: 239
# weights:   torch.Size([32, 1])
# steps: 240
# weights:   torch.Size([32, 1])
# steps: 241
# weights:   torch.Size([32, 1])
# steps: 242
# weights:   torch.Size([32, 1])
# steps: 243
# weights:   torch.Size([32, 1])
# steps: 244
# weights:   torch.Size([32, 1])
# steps: 245
# weights:   torch.Size([32, 1])
# steps: 246
# weights:   torch.Size([32, 1])
# steps: 247
# weights:   torch.Size([32, 1])
# steps: 248
# weights:   torch.Size([32, 1])
# steps: 249
# weights:   torch.Size([32, 1])
# steps: 250
# weights:   torch.Size([32, 1])
# steps: 251
# weights:   torch.Size([32, 1])
# steps: 252
# weights:   torch.Size([32, 1])
# steps: 253
# weights:   torch.Size([32, 1])
# steps: 254
# weights:   torch.Size([32, 1])
# steps: 255
# weights:   torch.Size([32, 1])
# steps: 256
# weights:   torch.Size([32, 1])
# steps: 257
# weights:   torch.Size([32, 1])
# steps: 258
# weights:   torch.Size([32, 1])
# steps: 259
# weights:   torch.Size([32, 1])
# steps: 260
# weights:   torch.Size([32, 1])
# steps: 261
# weights:   torch.Size([32, 1])
# steps: 262
# weights:   torch.Size([32, 1])
# steps: 263
# weights:   torch.Size([32, 1])
# steps: 264
# weights:   torch.Size([32, 1])
# steps: 265
# weights:   torch.Size([32, 1])
# steps: 266
# weights:   torch.Size([32, 1])
# steps: 267
# weights:   torch.Size([32, 1])
# steps: 268
# weights:   torch.Size([32, 1])
# steps: 269
# weights:   torch.Size([32, 1])
# steps: 270
# weights:   torch.Size([32, 1])
# steps: 271
# weights:   torch.Size([32, 1])
# steps: 272
# weights:   torch.Size([32, 1])
# steps: 273
# weights:   torch.Size([32, 1])
# steps: 274
# weights:   torch.Size([32, 1])
# steps: 275
# weights:   torch.Size([32, 1])
# steps: 276
# weights:   torch.Size([32, 1])
# steps: 277
# weights:   torch.Size([32, 1])
# steps: 278
# weights:   torch.Size([32, 1])
# steps: 279
# weights:   torch.Size([32, 1])
# steps: 280
# weights:   torch.Size([32, 1])
# steps: 281
# weights:   torch.Size([32, 1])
# steps: 282
# weights:   torch.Size([32, 1])
# steps: 283
# weights:   torch.Size([32, 1])
# steps: 284
# weights:   torch.Size([32, 1])
# steps: 285
# weights:   torch.Size([32, 1])
# steps: 286
# weights:   torch.Size([32, 1])
# steps: 287
# weights:   torch.Size([32, 1])
# steps: 288
# weights:   torch.Size([32, 1])
# steps: 289
# weights:   torch.Size([32, 1])
# steps: 290
# weights:   torch.Size([32, 1])
# steps: 291
# weights:   torch.Size([32, 1])
# steps: 292
# weights:   torch.Size([32, 1])
# steps: 293
# weights:   torch.Size([32, 1])
# steps: 294
# weights:   torch.Size([32, 1])
# steps: 295
# weights:   torch.Size([32, 1])
# steps: 296
# weights:   torch.Size([32, 1])
# steps: 297
# weights:   torch.Size([32, 1])
# steps: 298
# weights:   torch.Size([32, 1])
# steps: 299
# weights:   torch.Size([32, 1])
# steps: 300
# weights:   torch.Size([32, 1])
# 7.376999999999983
# 3.461999999999999
# Episode reward: 10.83899999999998
# episode: 1
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Red team starts
# steps: 0
# weights:   torch.Size([32, 1])
# steps: 1
# weights:   torch.Size([32, 1])
# steps: 2
# weights:   torch.Size([32, 1])
# steps: 3
# weights:   torch.Size([32, 1])
# steps: 4
# weights:   torch.Size([32, 1])
# steps: 5
# weights:   torch.Size([32, 1])
# steps: 6
# weights:   torch.Size([32, 1])
# steps: 7
# weights:   torch.Size([32, 1])
# steps: 8
# weights:   torch.Size([32, 1])
# steps: 9
# weights:   torch.Size([32, 1])
# steps: 10
# weights:   torch.Size([32, 1])
# steps: 11
# weights:   torch.Size([32, 1])
# steps: 12
# weights:   torch.Size([32, 1])
# steps: 13
# weights:   torch.Size([32, 1])
# steps: 14
# weights:   torch.Size([32, 1])
# steps: 15
# weights:   torch.Size([32, 1])
# steps: 16
# weights:   torch.Size([32, 1])
# steps: 17
# weights:   torch.Size([32, 1])
# steps: 18
# weights:   torch.Size([32, 1])
# steps: 19
# weights:   torch.Size([32, 1])
# steps: 20
# weights:   torch.Size([32, 1])
# steps: 21
# weights:   torch.Size([32, 1])
# steps: 22
# weights:   torch.Size([32, 1])
# steps: 23
# weights:   torch.Size([32, 1])
# steps: 24
# weights:   torch.Size([32, 1])
# steps: 25
# weights:   torch.Size([32, 1])
# steps: 26
# weights:   torch.Size([32, 1])
# steps: 27
# weights:   torch.Size([32, 1])
# steps: 28
# weights:   torch.Size([32, 1])
# steps: 29
# weights:   torch.Size([32, 1])
# steps: 30
# weights:   torch.Size([32, 1])
# steps: 31
# weights:   torch.Size([32, 1])
# steps: 32
# weights:   torch.Size([32, 1])
# steps: 33
# weights:   torch.Size([32, 1])
# steps: 34
# weights:   torch.Size([32, 1])
# steps: 35
# weights:   torch.Size([32, 1])
# steps: 36
# weights:   torch.Size([32, 1])
# steps: 37
# weights:   torch.Size([32, 1])
# steps: 38
# weights:   torch.Size([32, 1])
# steps: 39
# weights:   torch.Size([32, 1])
# steps: 40
# weights:   torch.Size([32, 1])
# steps: 41
# weights:   torch.Size([32, 1])
# steps: 42
# weights:   torch.Size([32, 1])
# steps: 43
# weights:   torch.Size([32, 1])
# steps: 44
# weights:   torch.Size([32, 1])
# steps: 45
# weights:   torch.Size([32, 1])
# steps: 46
# weights:   torch.Size([32, 1])
# steps: 47
# weights:   torch.Size([32, 1])
# steps: 48
# weights:   torch.Size([32, 1])
# steps: 49
# weights:   torch.Size([32, 1])
# steps: 50
# weights:   torch.Size([32, 1])
# steps: 51
# weights:   torch.Size([32, 1])
# steps: 52
# weights:   torch.Size([32, 1])
# steps: 53
# weights:   torch.Size([32, 1])
# steps: 54
# weights:   torch.Size([32, 1])
# steps: 55
# weights:   torch.Size([32, 1])
# steps: 56
# weights:   torch.Size([32, 1])
# steps: 57
# weights:   torch.Size([32, 1])
# steps: 58
# weights:   torch.Size([32, 1])
# steps: 59
# weights:   torch.Size([32, 1])
# steps: 60
# weights:   torch.Size([32, 1])
# steps: 61
# weights:   torch.Size([32, 1])
# steps: 62
# weights:   torch.Size([32, 1])
# steps: 63
# weights:   torch.Size([32, 1])
# steps: 64
# weights:   torch.Size([32, 1])
# steps: 65
# weights:   torch.Size([32, 1])
# steps: 66
# weights:   torch.Size([32, 1])
# steps: 67
# weights:   torch.Size([32, 1])
# steps: 68
# weights:   torch.Size([32, 1])
# steps: 69
# weights:   torch.Size([32, 1])
# steps: 70
# weights:   torch.Size([32, 1])
# steps: 71
# weights:   torch.Size([32, 1])
# steps: 72
# weights:   torch.Size([32, 1])
# steps: 73
# weights:   torch.Size([32, 1])
# steps: 74
# weights:   torch.Size([32, 1])
# steps: 75
# weights:   torch.Size([32, 1])
# steps: 76
# weights:   torch.Size([32, 1])
# steps: 77
# weights:   torch.Size([32, 1])
# steps: 78
# weights:   torch.Size([32, 1])
# steps: 79
# weights:   torch.Size([32, 1])
# steps: 80
# weights:   torch.Size([32, 1])
# steps: 81
# weights:   torch.Size([32, 1])
# steps: 82
# weights:   torch.Size([32, 1])
# steps: 83
# weights:   torch.Size([32, 1])
# steps: 84
# weights:   torch.Size([32, 1])
# steps: 85
# weights:   torch.Size([32, 1])
# steps: 86
# weights:   torch.Size([32, 1])
# steps: 87
# weights:   torch.Size([32, 1])
# steps: 88
# weights:   torch.Size([32, 1])
# steps: 89
# weights:   torch.Size([32, 1])
# steps: 90
# weights:   torch.Size([32, 1])
# steps: 91
# weights:   torch.Size([32, 1])
# steps: 92
# weights:   torch.Size([32, 1])
# steps: 93
# weights:   torch.Size([32, 1])
# steps: 94
# weights:   torch.Size([32, 1])
# steps: 95
# weights:   torch.Size([32, 1])
# steps: 96
# weights:   torch.Size([32, 1])
# steps: 97
# weights:   torch.Size([32, 1])
# steps: 98
# weights:   torch.Size([32, 1])
# steps: 99
# weights:   torch.Size([32, 1])
# steps: 100
# weights:   torch.Size([32, 1])
# steps: 101
# weights:   torch.Size([32, 1])
# steps: 102
# weights:   torch.Size([32, 1])
# steps: 103
# weights:   torch.Size([32, 1])
# steps: 104
# weights:   torch.Size([32, 1])
# steps: 105
# weights:   torch.Size([32, 1])
# steps: 106
# weights:   torch.Size([32, 1])
# steps: 107
# weights:   torch.Size([32, 1])
# steps: 108
# weights:   torch.Size([32, 1])
# steps: 109
# weights:   torch.Size([32, 1])
# steps: 110
# weights:   torch.Size([32, 1])
# steps: 111
# weights:   torch.Size([32, 1])
# steps: 112
# weights:   torch.Size([32, 1])
# steps: 113
# weights:   torch.Size([32, 1])
# steps: 114
# weights:   torch.Size([32, 1])
# steps: 115
# weights:   torch.Size([32, 1])
# steps: 116
# weights:   torch.Size([32, 1])
# steps: 117
# weights:   torch.Size([32, 1])
# steps: 118
# weights:   torch.Size([32, 1])
# steps: 119
# weights:   torch.Size([32, 1])
# steps: 120
# weights:   torch.Size([32, 1])
# steps: 121
# weights:   torch.Size([32, 1])
# steps: 122
# weights:   torch.Size([32, 1])
# steps: 123
# weights:   torch.Size([32, 1])
# steps: 124
# weights:   torch.Size([32, 1])
# steps: 125
# weights:   torch.Size([32, 1])
# steps: 126
# weights:   torch.Size([32, 1])
# steps: 127
# weights:   torch.Size([32, 1])
# steps: 128
# weights:   torch.Size([32, 1])
# steps: 129
# weights:   torch.Size([32, 1])
# steps: 130
# weights:   torch.Size([32, 1])
# steps: 131
# weights:   torch.Size([32, 1])
# steps: 132
# weights:   torch.Size([32, 1])
# steps: 133
# weights:   torch.Size([32, 1])
# steps: 134
# weights:   torch.Size([32, 1])
# steps: 135
# weights:   torch.Size([32, 1])
# steps: 136
# weights:   torch.Size([32, 1])
# steps: 137
# weights:   torch.Size([32, 1])
# steps: 138
# weights:   torch.Size([32, 1])
# steps: 139
# weights:   torch.Size([32, 1])
# steps: 140
# weights:   torch.Size([32, 1])
# steps: 141
# weights:   torch.Size([32, 1])
# steps: 142
# weights:   torch.Size([32, 1])
# steps: 143
# weights:   torch.Size([32, 1])
# steps: 144
# weights:   torch.Size([32, 1])
# steps: 145
# weights:   torch.Size([32, 1])
# steps: 146
# weights:   torch.Size([32, 1])
# steps: 147
# weights:   torch.Size([32, 1])
# steps: 148
# weights:   torch.Size([32, 1])
# steps: 149
# weights:   torch.Size([32, 1])
# steps: 150
# weights:   torch.Size([32, 1])
# steps: 151
# weights:   torch.Size([32, 1])
# steps: 152
# weights:   torch.Size([32, 1])
# steps: 153
# weights:   torch.Size([32, 1])
# steps: 154
# weights:   torch.Size([32, 1])
# steps: 155
# weights:   torch.Size([32, 1])
# steps: 156
# weights:   torch.Size([32, 1])
# steps: 157
# weights:   torch.Size([32, 1])
# steps: 158
# weights:   torch.Size([32, 1])
# steps: 159
# weights:   torch.Size([32, 1])
# steps: 160
# weights:   torch.Size([32, 1])
# steps: 161
# weights:   torch.Size([32, 1])
# steps: 162
# weights:   torch.Size([32, 1])
# steps: 163
# weights:   torch.Size([32, 1])
# steps: 164
# weights:   torch.Size([32, 1])
# steps: 165
# weights:   torch.Size([32, 1])
# steps: 166
# weights:   torch.Size([32, 1])
# steps: 167
# weights:   torch.Size([32, 1])
# steps: 168
# weights:   torch.Size([32, 1])
# steps: 169
# weights:   torch.Size([32, 1])
# steps: 170
# weights:   torch.Size([32, 1])
# steps: 171
# weights:   torch.Size([32, 1])
# steps: 172
# weights:   torch.Size([32, 1])
# steps: 173
# weights:   torch.Size([32, 1])
# steps: 174
# weights:   torch.Size([32, 1])
# steps: 175
# weights:   torch.Size([32, 1])
# steps: 176
# weights:   torch.Size([32, 1])
# steps: 177
# weights:   torch.Size([32, 1])
# steps: 178
# weights:   torch.Size([32, 1])
# steps: 179
# weights:   torch.Size([32, 1])
# steps: 180
# weights:   torch.Size([32, 1])
# steps: 181
# weights:   torch.Size([32, 1])
# steps: 182
# weights:   torch.Size([32, 1])
# steps: 183
# weights:   torch.Size([32, 1])
# steps: 184
# weights:   torch.Size([32, 1])
# steps: 185
# weights:   torch.Size([32, 1])
# steps: 186
# weights:   torch.Size([32, 1])
# steps: 187
# weights:   torch.Size([32, 1])
# steps: 188
# weights:   torch.Size([32, 1])
# steps: 189
# weights:   torch.Size([32, 1])
# steps: 190
# weights:   torch.Size([32, 1])
# steps: 191
# weights:   torch.Size([32, 1])
# steps: 192
# weights:   torch.Size([32, 1])
# steps: 193
# weights:   torch.Size([32, 1])
# steps: 194
# weights:   torch.Size([32, 1])
# steps: 195
# weights:   torch.Size([32, 1])
# steps: 196
# weights:   torch.Size([32, 1])
# steps: 197
# weights:   torch.Size([32, 1])
# steps: 198
# weights:   torch.Size([32, 1])
# steps: 199
# weights:   torch.Size([32, 1])
# steps: 200
# weights:   torch.Size([32, 1])
# steps: 201
# weights:   torch.Size([32, 1])
# steps: 202
# weights:   torch.Size([32, 1])
# steps: 203
# weights:   torch.Size([32, 1])
# steps: 204
# weights:   torch.Size([32, 1])
# steps: 205
# weights:   torch.Size([32, 1])
# steps: 206
# weights:   torch.Size([32, 1])
# steps: 207
# weights:   torch.Size([32, 1])
# steps: 208
# weights:   torch.Size([32, 1])
# steps: 209
# weights:   torch.Size([32, 1])
# steps: 210
# weights:   torch.Size([32, 1])
# steps: 211
# weights:   torch.Size([32, 1])
# steps: 212
# weights:   torch.Size([32, 1])
# steps: 213
# weights:   torch.Size([32, 1])
# steps: 214
# weights:   torch.Size([32, 1])
# steps: 215
# weights:   torch.Size([32, 1])
# steps: 216
# weights:   torch.Size([32, 1])
# steps: 217
# weights:   torch.Size([32, 1])
# steps: 218
# weights:   torch.Size([32, 1])
# steps: 219
# weights:   torch.Size([32, 1])
# steps: 220
# weights:   torch.Size([32, 1])
# steps: 221
# weights:   torch.Size([32, 1])
# steps: 222
# weights:   torch.Size([32, 1])
# steps: 223
# weights:   torch.Size([32, 1])
# steps: 224
# weights:   torch.Size([32, 1])
# steps: 225
# weights:   torch.Size([32, 1])
# steps: 226
# weights:   torch.Size([32, 1])
# steps: 227
# weights:   torch.Size([32, 1])
# steps: 228
# weights:   torch.Size([32, 1])
# steps: 229
# weights:   torch.Size([32, 1])
# steps: 230
# weights:   torch.Size([32, 1])
# steps: 231
# weights:   torch.Size([32, 1])
# steps: 232
# weights:   torch.Size([32, 1])
# steps: 233
# weights:   torch.Size([32, 1])
# steps: 234
# weights:   torch.Size([32, 1])
# steps: 235
# weights:   torch.Size([32, 1])
# steps: 236
# weights:   torch.Size([32, 1])
# steps: 237
# weights:   torch.Size([32, 1])
# steps: 238
# weights:   torch.Size([32, 1])
# steps: 239
# weights:   torch.Size([32, 1])
# steps: 240
# weights:   torch.Size([32, 1])
# steps: 241
# weights:   torch.Size([32, 1])
# steps: 242
# weights:   torch.Size([32, 1])
# steps: 243
# weights:   torch.Size([32, 1])
# steps: 244
# weights:   torch.Size([32, 1])
# steps: 245
# weights:   torch.Size([32, 1])
# steps: 246
# weights:   torch.Size([32, 1])
# steps: 247
# weights:   torch.Size([32, 1])
# steps: 248
# weights:   torch.Size([32, 1])
# steps: 249
# weights:   torch.Size([32, 1])
# steps: 250
# weights:   torch.Size([32, 1])
# steps: 251
# weights:   torch.Size([32, 1])
# steps: 252
# weights:   torch.Size([32, 1])
# steps: 253
# weights:   torch.Size([32, 1])
# steps: 254
# weights:   torch.Size([32, 1])
# steps: 255
# weights:   torch.Size([32, 1])
# steps: 256
# weights:   torch.Size([32, 1])
# steps: 257
# weights:   torch.Size([32, 1])
# steps: 258
# weights:   torch.Size([32, 1])
# steps: 259
# weights:   torch.Size([32, 1])
# steps: 260
# weights:   torch.Size([32, 1])
# steps: 261
# weights:   torch.Size([32, 1])
# steps: 262
# weights:   torch.Size([32, 1])
# steps: 263
# weights:   torch.Size([32, 1])
# steps: 264
# weights:   torch.Size([32, 1])
# steps: 265
# weights:   torch.Size([32, 1])
# steps: 266
# weights:   torch.Size([32, 1])
# steps: 267
# weights:   torch.Size([32, 1])
# steps: 268
# weights:   torch.Size([32, 1])
# steps: 269
# weights:   torch.Size([32, 1])
# steps: 270
# weights:   torch.Size([32, 1])
# steps: 271
# weights:   torch.Size([32, 1])
# steps: 272
# weights:   torch.Size([32, 1])
# steps: 273
# weights:   torch.Size([32, 1])
# steps: 274
# weights:   torch.Size([32, 1])
# steps: 275
# weights:   torch.Size([32, 1])
# steps: 276
# weights:   torch.Size([32, 1])
# steps: 277
# weights:   torch.Size([32, 1])
# steps: 278
# weights:   torch.Size([32, 1])
# steps: 279
# weights:   torch.Size([32, 1])
# steps: 280
# weights:   torch.Size([32, 1])
# steps: 281
# weights:   torch.Size([32, 1])
# steps: 282
# weights:   torch.Size([32, 1])
# steps: 283
# weights:   torch.Size([32, 1])
# steps: 284
# weights:   torch.Size([32, 1])
# steps: 285
# weights:   torch.Size([32, 1])
# steps: 286
# weights:   torch.Size([32, 1])
# steps: 287
# weights:   torch.Size([32, 1])
# steps: 288
# weights:   torch.Size([32, 1])
# steps: 289
# weights:   torch.Size([32, 1])
# steps: 290
# weights:   torch.Size([32, 1])
# steps: 291
# weights:   torch.Size([32, 1])
# steps: 292
# weights:   torch.Size([32, 1])
# steps: 293
# weights:   torch.Size([32, 1])
# steps: 294
# weights:   torch.Size([32, 1])
# steps: 295
# weights:   torch.Size([32, 1])
# steps: 296
# weights:   torch.Size([32, 1])
# steps: 297
# weights:   torch.Size([32, 1])
# steps: 298
# weights:   torch.Size([32, 1])
# steps: 299
# weights:   torch.Size([32, 1])
# steps: 300
# weights:   torch.Size([32, 1])
# 5.891999999999994
# 4.954000000000006
# Episode reward: 10.846
# episode: 2
# enemy: randomTeam.py
# Loading Team: c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py
# Arguments: {}
# Blue team starts
# steps: 0
# weights:   torch.Size([32, 1])
# steps: 1
# weights:   torch.Size([32, 1])
# steps: 2
# weights:   torch.Size([32, 1])
# steps: 3
# weights:   torch.Size([32, 1])
# steps: 4
# weights:   torch.Size([32, 1])
# steps: 5
# weights:   torch.Size([32, 1])
# steps: 6
# weights:   torch.Size([32, 1])
# steps: 7
# weights:   torch.Size([32, 1])
# steps: 8
# weights:   torch.Size([32, 1])
# steps: 9
# weights:   torch.Size([32, 1])
# steps: 10
# weights:   torch.Size([32, 1])
# steps: 11
# weights:   torch.Size([32, 1])
# steps: 12
# weights:   torch.Size([32, 1])
# steps: 13
# weights:   torch.Size([32, 1])
# steps: 14
# weights:   torch.Size([32, 1])
# steps: 15
# weights:   torch.Size([32, 1])
# steps: 16
# weights:   torch.Size([32, 1])
# steps: 17
# weights:   torch.Size([32, 1])
# steps: 18
# weights:   torch.Size([32, 1])
# steps: 19
# weights:   torch.Size([32, 1])
# steps: 20
# weights:   torch.Size([32, 1])
# steps: 21
# weights:   torch.Size([32, 1])
# steps: 22
# weights:   torch.Size([32, 1])
# steps: 23
# weights:   torch.Size([32, 1])
# steps: 24
# weights:   torch.Size([32, 1])
# steps: 25
# weights:   torch.Size([32, 1])
# steps: 26
# weights:   torch.Size([32, 1])
# steps: 27
# weights:   torch.Size([32, 1])
# steps: 28
# weights:   torch.Size([32, 1])
# steps: 29
# weights:   torch.Size([32, 1])
# steps: 30
# weights:   torch.Size([32, 1])
# steps: 31
# weights:   torch.Size([32, 1])
# steps: 32
# weights:   torch.Size([32, 1])
# steps: 33
# weights:   torch.Size([32, 1])
# steps: 34
# weights:   torch.Size([32, 1])
# steps: 35
# weights:   torch.Size([32, 1])
# steps: 36
# weights:   torch.Size([32, 1])
# steps: 37
# weights:   torch.Size([32, 1])
# steps: 38
# weights:   torch.Size([32, 1])
# steps: 39
# weights:   torch.Size([32, 1])
# steps: 40
# weights:   torch.Size([32, 1])
# steps: 41
# weights:   torch.Size([32, 1])
# steps: 42
# weights:   torch.Size([32, 1])
# steps: 43
# weights:   torch.Size([32, 1])
# steps: 44
# weights:   torch.Size([32, 1])
# steps: 45
# weights:   torch.Size([32, 1])
# steps: 46
# weights:   torch.Size([32, 1])
# steps: 47
# weights:   torch.Size([32, 1])
# steps: 48
# weights:   torch.Size([32, 1])
# steps: 49
# weights:   torch.Size([32, 1])
# steps: 50
# weights:   torch.Size([32, 1])
# steps: 51
# weights:   torch.Size([32, 1])
# steps: 52
# weights:   torch.Size([32, 1])
# steps: 53
# weights:   torch.Size([32, 1])
# steps: 54
# weights:   torch.Size([32, 1])
# steps: 55
# weights:   torch.Size([32, 1])
# steps: 56
# weights:   torch.Size([32, 1])
# steps: 57
# weights:   torch.Size([32, 1])
# steps: 58
# weights:   torch.Size([32, 1])
# steps: 59
# weights:   torch.Size([32, 1])
# steps: 60
# weights:   torch.Size([32, 1])
# steps: 61
# weights:   torch.Size([32, 1])
# steps: 62
# weights:   torch.Size([32, 1])
# steps: 63
# weights:   torch.Size([32, 1])
# steps: 64
# weights:   torch.Size([32, 1])
# steps: 65
# weights:   torch.Size([32, 1])
# steps: 66
# weights:   torch.Size([32, 1])
# steps: 67
# weights:   torch.Size([32, 1])
# steps: 68
# weights:   torch.Size([32, 1])
# steps: 69
# weights:   torch.Size([32, 1])
# steps: 70
# weights:   torch.Size([32, 1])
# steps: 71
# weights:   torch.Size([32, 1])
# steps: 72
# weights:   torch.Size([32, 1])
# steps: 73
# weights:   torch.Size([32, 1])
# steps: 74
# weights:   torch.Size([32, 1])
# steps: 75
# weights:   torch.Size([32, 1])
# steps: 76
# weights:   torch.Size([32, 1])
# steps: 77
# weights:   torch.Size([32, 1])
# steps: 78
# weights:   torch.Size([32, 1])
# steps: 79
# weights:   torch.Size([32, 1])
# steps: 80
# weights:   torch.Size([32, 1])
# steps: 81
# weights:   torch.Size([32, 1])
# steps: 82
# weights:   torch.Size([32, 1])
# steps: 83
# weights:   torch.Size([32, 1])
# steps: 84
# weights:   torch.Size([32, 1])
# steps: 85
# weights:   torch.Size([32, 1])
# steps: 86
# weights:   torch.Size([32, 1])
# steps: 87
# weights:   torch.Size([32, 1])
# steps: 88
# weights:   torch.Size([32, 1])
# steps: 89
# weights:   torch.Size([32, 1])
# steps: 90
# weights:   torch.Size([32, 1])
# steps: 91
# weights:   torch.Size([32, 1])
# steps: 92
# weights:   torch.Size([32, 1])
# steps: 93
# weights:   torch.Size([32, 1])
# steps: 94
# weights:   torch.Size([32, 1])
# steps: 95
# weights:   torch.Size([32, 1])
# steps: 96
# weights:   torch.Size([32, 1])
# steps: 97
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[279], line 31
#      27 wandb.init(entity = team_name, project="PacManCapture", id = f"{name_experiment}__{datetime.now().strftime('%Y%m%d_%H%M%S')}")
#      29 #pr = cProfile.Profile()
#      30 #pr.enable()
# ---> 31 train_qmix(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p_qmix, learn_p_qmix, later_exploration=True, individual_reward=True)
#      32 #pr.disable()
#      33 wandb.finish()
#
# Cell In[270], line 125, in train_qmix(env, name_experiment, agent_q_networks, target_q_networks, mixing_network, replay_buffer, train_p, learn_p, random_enemy, schedule, later_exploration, individual_reward)
#     122 elif type(replay_buffer) == ReplayBuffer:
#     123     batch = replay_buffer.sample(batch_size)
# --> 125 loss = compute_td_loss_qmix(agent_q_networks, target_q_networks,mixing_network, batch,
#     126                                gamma=gamma, weights=weights)
#     128 wandb.log({"loss": loss})
#     131 # Zero gradients for all optimizers
#
# Cell In[261], line 41, in compute_td_loss_qmix(agent_q_networks, target_q_networks, mixing_network, batch, weights, gamma, lambda_)
#      37 target_q_tot = rewards.sum(dim=2) + gamma * target_q_tot
#      40 # Compute the global Q-value using the mixing network
# ---> 41 q_tot = mixing_network(agent_qs, states).squeeze(1)  # Shape: (batch_size, 1)
#      42 # Compute Huber loss
#      43 td_loss = F.huber_loss(target_q_tot, q_tot,  reduction="none")
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[128], line 53, in SimpleQMixer.forward(self, agent_qs, agent_states)
#      50 agent_states_r = agent_states.view(batch_size * num_agents, channels, height, width)  # [batch_size * n_agents, channels, H, W]
#      52 conv_features = self.conv(agent_states_r)  # [batch_size * n_agents, conv_channels, H, W]
# ---> 53 flattened_features = conv_features.view(batch_size, num_agents, -1)  # [batch_size, n_agents, conv_output_size]
#      55 combined_features = flattened_features.view(batch_size, -1)  # [batch_size, n_agents * conv_output_size]
#      57 w = torch.abs(self.hyper_w(combined_features)).view(batch_size, self.n_agents, 1)
#
# File c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\fx\traceback.py:72, in format_stack()
#      69     return [current_meta.get("stack_trace", "")]
#      70 else:
#      71     # fallback to traceback.format_stack()
# ---> 72     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:232, in extract_stack(f, limit)
#     230 if f is None:
#     231     f = sys._getframe().f_back
# --> 232 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     233 stack.reverse()
#     234 return stack
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:395, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     392     for f, lineno in frame_gen:
#     393         yield f, (lineno, None, None, None)
# --> 395 return klass._extract_from_extended_frame_gen(
#     396     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     397     capture_locals=capture_locals)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:434, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     430     result.append(FrameSummary(
#     431         filename, lineno, name, lookup_line=False, locals=f_locals,
#     432         end_lineno=end_lineno, colno=colno, end_colno=end_colno))
#     433 for filename in fnames:
# --> 434     linecache.checkcache(filename)
#     435 # If immediate lookup was desired, trigger lookups now.
#     436 if lookup_lines:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except (OSError, ValueError):
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
s = StringIO()
sortby = 'cumtime'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
#          19785700 function calls (19699203 primitive calls) in 138.883 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   161/136    0.002    0.000   61.557    0.453 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\mailbox.py:121(_wait)
#   154/146   52.722    0.342   52.838    0.362 {method 'recv' of '_socket.socket' objects}
#       146    0.003    0.000   51.953    0.356 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:282(read_server_response)
#       146    0.003    0.000   51.939    0.356 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:239(_read_packet_bytes)
#    162/23    0.004    0.000   26.700    1.161 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\mailbox.py:124(_get_and_clear)
# 2751/2727    0.013    0.000   14.964    0.005 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\events.py:86(_run)
# 9210/1095    0.026    0.000   14.304    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1732(_wrapped_call_impl)
#     13153    0.063    0.000   14.099    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\fx\traceback.py:66(format_stack)
# 9210/1095    0.039    0.000   14.088    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1740(_call_impl)
#       923    0.045    0.000   11.364    0.012 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1737995069.py:12(forward)
# 6341/4742   56.119    0.009   10.614    0.002 {method 'acquire' of '_thread.lock' objects}
#     13153    0.048    0.000   10.485    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:221(extract_stack)
#     13153    0.035    0.000   10.392    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:377(extract)
#     13153    1.099    0.000   10.354    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:399(_extract_from_extended_frame_gen)
#        87    0.050    0.001    8.091    0.093 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\427276882.py:40(compute_td_errors)
#        87    0.059    0.001    7.369    0.085 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\427276882.py:10(sample)
#    244161    0.235    0.000    7.255    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:52(checkcache)
#    179917    6.990    0.000    6.990    0.000 {built-in method nt.stat}
#        86    0.054    0.001    6.433    0.075 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1998007249.py:1(compute_td_loss_qmix)
# 2751/2727    0.017    0.000    6.042    0.002 {method 'run' of '_contextvars.Context' objects}
#  2287/220    0.059    0.000    5.132    0.023 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:1915(_run_once)
#      2532    0.005    0.000    4.395    0.002 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\linear.py:124(forward)
#      2532    0.315    0.000    4.386    0.002 {built-in method torch._C._nn.linear}
#      3285    0.008    0.000    4.109    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\conv.py:553(forward)
#      3285    0.008    0.000    4.088    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\conv.py:536(_conv_forward)
#      3285    0.520    0.000    4.080    0.001 {built-in method torch.conv2d}
#     13153    0.025    0.000    3.546    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:29(format_list)
#     13153    0.313    0.000    3.272    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:525(format)
#      4550    0.259    0.000    3.213    0.001 {built-in method torch.relu}
#    403133    1.215    0.000    2.886    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:460(format_frame_summary)
#       172    0.016    0.000    2.693    0.016 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\3786083693.py:39(forward)
#        86    0.001    0.000    2.662    0.031 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_tensor.py:525(backward)
#        86    0.001    0.000    2.631    0.031 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\autograd\__init__.py:242(backward)
#        86    0.001    0.000    2.622    0.030 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\autograd\graph.py:816(_engine_run_backward)
#        86    2.621    0.030    2.621    0.030 {method 'run_backward' of 'torch._C._EngineBase' objects}
# 2289/2254    0.021    0.000    2.157    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\selectors.py:319(select)
# 2289/2254    0.207    0.000    2.078    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\selectors.py:313(_select)
#       516    0.008    0.000    1.861    0.004 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\container.py:248(forward)
#   1949900    0.632    0.000    1.547    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:318(line)
#       236    0.009    0.000    1.305    0.006 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1032643252.py:2(epsilon_greedy_action)
#         1    0.001    0.001    1.111    1.111 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\886085567.py:4(train_qmix)
#      1989    0.007    0.000    0.922    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\ioloop.py:742(_run_callback)
#       922    0.002    0.000    0.735    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\pooling.py:1454(forward)
#       922    0.004    0.000    0.734    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\functional.py:1370(adaptive_avg_pool2d)
#       922    0.059    0.000    0.724    0.001 {built-in method torch._C._nn.adaptive_avg_pool2d}
#       533    0.002    0.000    0.698    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\redirect.py:644(write)
#         1    0.001    0.001    0.678    0.678 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\gymPacMan.py:93(reset)
#         2    0.079    0.039    0.653    0.326 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py:62(registerInitialState)
#    429439    0.152    0.000    0.651    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:391(extended_frame_gen)
#       264    0.002    0.000    0.650    0.002 {built-in method builtins.print}
#      1161    0.632    0.001    0.632    0.001 {method 'to' of 'torch._C.TensorBase' objects}
#         2    0.000    0.000    0.621    0.310 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:1441(structured_traceback)
#         2    0.000    0.000    0.621    0.310 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:1343(structured_traceback)
#         2    0.000    0.000    0.621    0.310 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:1186(structured_traceback)
#         2    0.000    0.000    0.621    0.310 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:1061(format_exception_as_a_whole)
#       922    0.023    0.000    0.614    0.001 {built-in method torch.flatten}
#         2    0.000    0.000    0.607    0.303 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:2115(showtraceback)
#         3    0.000    0.000    0.595    0.198 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\distanceCalculator.py:35(getMazeDistances)
#         3    0.000    0.000    0.595    0.198 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\distanceCalculator.py:99(run)
#         3    0.310    0.103    0.595    0.198 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\distanceCalculator.py:111(computeDistances)
#       860    0.002    0.000    0.580    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\activation.py:132(forward)
#       860    0.001    0.000    0.579    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\functional.py:1693(relu)
#     18701    0.437    0.000    0.576    0.000 {method 'cpu' of 'torch._C.TensorBase' objects}
#       689    0.056    0.000    0.554    0.001 {method 'gather' of 'torch._C.TensorBase' objects}
#    416287    0.256    0.000    0.533    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:26(getline)
#       118    0.006    0.000    0.501    0.004 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\gymPacMan.py:144(step)
#    429439    0.499    0.000    0.499    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:327(walk_stack)
#   2330880    0.440    0.000    0.440    0.000 {method 'strip' of 'str' objects}
#       533    0.001    0.000    0.435    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\colorama\ansitowin32.py:46(write)
#      2168    0.011    0.000    0.435    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:583(_handle_events)
#       533    0.001    0.000    0.432    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\colorama\ansitowin32.py:175(write)
#       533    0.002    0.000    0.428    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\colorama\ansitowin32.py:192(write_and_convert)
#    779984    0.418    0.000    0.418    0.000 {method 'format' of 'str' objects}
#   2320770    0.410    0.000    0.410    0.000 {method 'append' of 'list' objects}
#       712    0.064    0.000    0.390    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\gymPacMan.py:202(get_Observation)
#       533    0.006    0.000    0.385    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\colorama\ansitowin32.py:208(write_plain_text)
#         2    0.000    0.000    0.382    0.191 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\captureAgents.py:91(registerInitialState)
#       860    0.014    0.000    0.359    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#        12    0.000    0.000    0.353    0.029 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:876(format_record)
#     89/36    0.000    0.000    0.351    0.010 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:141(cached_property_wrapper)
#       619    0.002    0.000    0.324    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:392(wrapper_fn)
#      1768    0.067    0.000    0.305    0.000 {built-in method torch.cat}
#   2345547    0.297    0.000    0.297    0.000 {built-in method builtins.len}
#      3442    0.286    0.000    0.289    0.000 {built-in method torch.tensor}
#       532    0.001    0.000    0.285    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:2362(<lambda>)
#       533    0.013    0.000    0.284    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:1514(_console_raw_callback)
# 2288/2238    6.734    0.003    0.283    0.000 {built-in method select.select}
#      2166    0.005    0.000    0.282    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:624(_handle_recv)
#    376827    0.107    0.000    0.270    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:312(_original_line)
#        12    0.000    0.000    0.255    0.021 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:195(_format_traceback_lines)
#       533    0.007    0.000    0.255    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface.py:704(publish_output_raw)
#        61    0.000    0.000    0.255    0.004 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:375(render)
#        12    0.000    0.000    0.254    0.021 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:799(_pygmented_scope_lines)
#        12    0.000    0.000    0.252    0.021 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:151(_pygmented_with_ranges)
#     13153    0.144    0.000    0.249    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:441(from_list)
#      2168    0.005    0.000    0.249    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:556(_run_callback)
#      1446    0.002    0.000    0.242    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:694(<lambda>)
#      2164    0.007    0.000    0.229    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:157(_handle_event)
#         2    0.000    0.000    0.227    0.114 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:1128(get_records)
#       722    0.001    0.000    0.227    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\platform\asyncio.py:200(_handle_events)
#    416286    0.156    0.000    0.226    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:149(lazycache)
#    416295    0.144    0.000    0.223    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:36(getlines)
#      3550    0.113    0.000    0.222    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:332(halfGrid)
#        16    0.000    0.000    0.217    0.014 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:562(stack_data)
#        16    0.000    0.000    0.217    0.014 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:75(collapse_repeated)
#        14    0.000    0.000    0.217    0.015 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:586(mapper)
#        14    0.000    0.000    0.216    0.015 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:546(__init__)
#        14    0.000    0.000    0.216    0.015 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:231(executing)
#         8    0.000    0.000    0.209    0.026 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:177(for_frame)
#         8    0.000    0.000    0.209    0.026 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:185(for_filename)
#         8    0.000    0.000    0.209    0.026 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:214(_for_filename_and_lines)
#         5    0.029    0.006    0.208    0.042 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:146(__init__)
#       472    0.006    0.000    0.204    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\gymPacMan.py:238(get_reward)
#     145/2    0.002    0.000    0.202    0.101 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\router_sock.py:25(_read_message)
# 416263/413227    0.129    0.000    0.201    0.000 {method 'join' of 'str' objects}
#    433200    0.135    0.000    0.192    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\layout.py:64(isWall)
#       258    0.019    0.000    0.187    0.001 {built-in method torch.abs}
#       172    0.005    0.000    0.176    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:467(wrapper)
#       430    0.007    0.000    0.174    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
#        12    0.000    0.000    0.160    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\__init__.py:77(highlight)
#        12    0.000    0.000    0.160    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\__init__.py:52(format)
#        12    0.000    0.000    0.159    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\formatters\terminal256.py:249(format)
#        12    0.000    0.000    0.159    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\formatter.py:114(format)
#        12    0.011    0.001    0.159    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\formatters\terminal256.py:252(format_unencoded)
#       172    0.003    0.000    0.151    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:72(_use_grad)
#      2839    0.147    0.000    0.147    0.000 {built-in method numpy.array}
#       172    0.002    0.000    0.147    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\adam.py:189(step)
#       657    0.003    0.000    0.143    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface_sock.py:49(_publish)
#       657    0.002    0.000    0.139    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:219(send_record_publish)
#      6488    0.007    0.000    0.139    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:156(get_tokens)
#      1082    0.008    0.000    0.135    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:616(_flush)
#       533    0.003    0.000    0.128    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface_shared.py:76(_publish_output_raw)
#   1290234    0.127    0.000    0.127    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\game.py:183(__getitem__)
#      6488    0.002    0.000    0.126    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:269(streamer)
#      6488    0.041    0.000    0.124    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:700(get_tokens_unprocessed)
#       172    0.001    0.000    0.117    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:140(maybe_fallback)
#       172    0.006    0.000    0.116    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\adam.py:717(adam)
#      1775    0.001    0.000    0.114    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:156(getBlueFood)
#      1775    0.001    0.000    0.110    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:148(getRedFood)
#       172    0.009    0.000    0.100    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\adam.py:439(_multi_tensor_adam)
#      4310    0.015    0.000    0.097    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
# 715245/710869    0.086    0.000    0.097    0.000 {built-in method builtins.isinstance}
#        12    0.000    0.000    0.096    0.008 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:799(lines)
#        12    0.000    0.000    0.096    0.008 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:718(lines)
#        12    0.000    0.000    0.096    0.008 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:666(included_pieces)
#        12    0.000    0.000    0.095    0.008 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:604(scope_pieces)
#    416352    0.095    0.000    0.095    0.000 {method 'add' of 'set' objects}
#       172    0.012    0.000    0.095    0.001 {built-in method torch.bmm}
#        86    0.001    0.000    0.093    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\functional.py:3681(huber_loss)
#         5    0.000    0.000    0.090    0.018 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:94(pieces)
#        86    0.009    0.000    0.090    0.001 {built-in method torch._C._nn.huber_loss}
#        24    0.000    0.000    0.089    0.004 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:651(__call__)
#      1506    0.002    0.000    0.089    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:112(_clean_pieces)
#        12    0.000    0.000    0.088    0.007 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:594(process_tokendef)
#  1056/396    0.004    0.000    0.088    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:551(_process_state)
#        86    0.008    0.000    0.085    0.001 {method 'mean' of 'torch._C.TensorBase' objects}
# 9512/1764    0.007    0.000    0.085    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:155(_raw_split_into_pieces)
#   544/543    0.006    0.000    0.083    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:754(send)
#       294    0.044    0.000    0.082    0.000 {method 'settimeout' of '_socket.socket' objects}
#    416286    0.081    0.000    0.081    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\traceback.py:265(__init__)
#      2172    0.005    0.000    0.081    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:663(_rebuild_io_state)
#      1320    0.001    0.000    0.081    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:504(_process_regex)
#    233306    0.080    0.000    0.080    0.000 {method 'match' of 're.Pattern' objects}
#      1428    0.001    0.000    0.078    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:177(line_range)
#    108300    0.040    0.000    0.078    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\util.py:180(pop)
#        96    0.000    0.000    0.078    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\lexer.py:494(get)
#        96    0.000    0.000    0.077    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\regexopt.py:82(regex_opt)
#   8064/96    0.020    0.000    0.077    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\regexopt.py:26(regex_opt_inner)
#       554    0.001    0.000    0.074    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:111(group_by_key_func)
#    376827    0.074    0.000    0.074    0.000 {method 'lstrip' of 'str' objects}
#     65482    0.037    0.000    0.073    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:269(iter_child_nodes)
#  9144/288    0.012    0.000    0.072    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\regexopt.py:77(<genexpr>)
#     18701    0.072    0.000    0.072    0.000 {method 'numpy' of 'torch._C.TensorBase' objects}
#      1428    0.001    0.000    0.070    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:29(line_range)
#    108300    0.045    0.000    0.070    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\util.py:172(push)
#      1464    0.001    0.000    0.070    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\asttokens.py:385(get_text_positions)
#      1464    0.005    0.000    0.066    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\asttokens.py:319(_get_text_positions_tokenless)
#      4342    0.014    0.000    0.064    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\sugar\attrsettr.py:43(__getattr__)
#       543    0.005    0.000    0.061    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:690(serialize)
#      2174    0.005    0.000    0.059    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:686(_update_handler)
#       657    0.001    0.000    0.054    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:153(send_server_request)
# 5965/4999    0.062    0.000    0.053    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\sugar\socket.py:626(send)
#    108870    0.037    0.000    0.053    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\util.py:185(isEmpty)
#       657    0.004    0.000    0.053    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:145(_send_message)
#       541    0.002    0.000    0.051    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:276(<lambda>)
#   14433/5    0.009    0.000    0.051    0.010 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:403(visit)
#   14282/5    0.018    0.000    0.051    0.010 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:409(generic_visit)
#      2344    0.006    0.000    0.051    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:183(dumps)
#     14438    0.009    0.000    0.050    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:369(walk)
#      1180    0.004    0.000    0.047    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:107(generateSuccessor)
#        20    0.000    0.000    0.047    0.002 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:488(visit_ClassDef)
#   151/132    0.001    0.000    0.046    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:453(visit_FunctionDef)
#       657    0.004    0.000    0.044    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\sock_client.py:121(_sendall_with_error_handle)
#       541    0.003    0.000    0.044    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:278(_really_send)
#      2344    0.004    0.000    0.044    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\json\encoder.py:183(encode)
# 2164/1647    0.007    0.000    0.042    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:259(schedule)
#      4733    0.042    0.000    0.042    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\game.py:170(__init__)
#      2172    0.003    0.000    0.041    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:92(json_packer)
#    108851    0.039    0.000    0.040    0.000 {built-in method _heapq.heappop}
#     14433    0.007    0.000    0.039    0.000 {method 'extend' of 'collections.deque' objects}
#    127877    0.028    0.000    0.039    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:257(iter_fields)
#      4342    0.033    0.000    0.038    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\sugar\attrsettr.py:66(_get_attr_opt)
#     26306    0.019    0.000    0.038    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\linecache.py:80(updatecache)
#        14    0.016    0.001    0.038    0.003 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:988(getmodule)
#   543/541    0.006    0.000    0.038    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\sugar\socket.py:703(send_multipart)
#        86    0.000    0.000    0.037    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:413(wrapper)
#      2344    0.016    0.000    0.037    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\json\encoder.py:205(iterencode)
#      6522    0.014    0.000    0.037    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\enum.py:1556(__and__)
#      2892    0.022    0.000    0.037    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\line_numbers.py:37(from_utf8_col)
#        86    0.000    0.000    0.037    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:359(wrapper)
#        86    0.000    0.000    0.036    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:1675(log)
#        86    0.001    0.000    0.036    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:1637(_log)
#      2166    0.020    0.000    0.035    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\sugar\socket.py:774(recv_multipart)
#       661    0.034    0.000    0.034    0.000 {method 'send' of '_socket.socket' objects}
#        86    0.001    0.000    0.033    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_run.py:1486(_partial_history_callback)
#        86    0.002    0.000    0.032    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface.py:617(publish_partial_history)
#    126981    0.031    0.000    0.031    0.000 {built-in method builtins.getattr}
#     35880    0.019    0.000    0.029    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\enum.py:1538(_get_value)
#         2    0.000    0.000    0.028    0.014 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\kernelbase.py:536(dispatch_queue)
#         4    0.000    0.000    0.028    0.007 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\kernelbase.py:522(process_one)
#       174    0.000    0.000    0.028    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_compile.py:22(inner)
#       174    0.000    0.000    0.027    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_dynamo\eval_frame.py:628(_fn)
#       533    0.005    0.000    0.027    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:655(write)
#    108847    0.026    0.000    0.026    0.000 {built-in method _heapq.heappush}
#       118    0.001    0.000    0.026    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\gymPacMan.py:268(check_termination)
#         2    0.000    0.000    0.026    0.013 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\ipkernel.py:358(execute_request)
#       172    0.010    0.000    0.026    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:916(zero_grad)
#      5438    0.009    0.000    0.025    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\enum.py:1545(__or__)
#         7    0.002    0.000    0.025    0.004 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:34(parse)
#     53173    0.025    0.000    0.025    0.000 {method 'startswith' of 'str' objects}
#      9210    0.025    0.000    0.025    0.000 {built-in method torch._C._get_tracing_state}
#         2    0.000    0.000    0.024    0.012 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\ipkernel.py:364(do_execute)
#         8    0.000    0.000    0.024    0.003 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\events.py:74(trigger)
#       545    0.002    0.000    0.024    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:592(flush)
#      2504    0.024    0.000    0.024    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        17    0.024    0.001    0.024    0.001 {built-in method builtins.compile}
#         2    0.000    0.000    0.024    0.012 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\zmqshell.py:546(run_cell)
#         8    0.000    0.000    0.024    0.003 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1529(info)
#         2    0.000    0.000    0.024    0.012 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:3042(run_cell)
# 2247/1456    0.005    0.000    0.023    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\util.py:406(last_stmt)
#        16    0.000    0.000    0.023    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1660(_log)
#         2    0.000    0.000    0.022    0.011 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\wandb_init.py:429(_pause_backend)
#        16    0.000    0.000    0.022    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1686(handle)
#        16    0.000    0.000    0.022    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1746(callHandlers)
#      1180    0.006    0.000    0.022    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:468(applyAction)
#        24    0.000    0.000    0.021    0.001 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1011(handle)
#      7992    0.014    0.000    0.021    0.000 <frozen genericpath>:81(commonprefix)
#   761/545    0.008    0.000    0.021    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\threading.py:637(wait)
#       236    0.002    0.000    0.021    0.000 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\1974295533.py:3(calculate_individual_reward)
#       533    0.002    0.000    0.020    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:577(_schedule_flush)
#      3560    0.020    0.000    0.020    0.000 {built-in method torch.zeros}
#       344    0.002    0.000    0.019    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\autograd\profiler.py:738(__exit__)
#      2600    0.004    0.000    0.019    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:453(getLegalActions)
#       541    0.002    0.000    0.019    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:271(send_multipart)
#      5848    0.009    0.000    0.019    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:101(_get_value)
#       172    0.011    0.000    0.019    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\adam.py:114(_init_group)
#     17685    0.018    0.000    0.018    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\nn\modules\module.py:1918(__getattr__)
#         1    0.000    0.000    0.018    0.018 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:369(newGame)
#     60625    0.018    0.000    0.018    0.000 {built-in method builtins.hasattr}
#     52712    0.017    0.000    0.017    0.000 {method 'endswith' of 'str' objects}
#      6942    0.005    0.000    0.017    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.017    0.017 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\decorator.py:229(fun)
#      1181    0.003    0.000    0.017    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:241(__init__)
#       344    0.001    0.000    0.017    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_ops.py:939(__call__)
#     18512    0.010    0.000    0.017    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\enum.py:720(__call__)
#   748/532    0.009    0.000    0.016    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\threading.py:323(wait)
#       533    0.002    0.000    0.016    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\google\protobuf\internal\well_known_types.py:176(GetCurrentTime)
#     27918    0.011    0.000    0.016    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:1143(node_linenos)
#      7732    0.004    0.000    0.015    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\util.py:140(iter_children_ast)
#       172    0.000    0.000    0.015    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\util.py:812(json_dumps_safer_history)
#       469    0.003    0.000    0.015    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\numpy\_core\fromnumeric.py:69(_wrapreduction)
#       545    0.002    0.000    0.015    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:675(sign)
#      1974    0.002    0.000    0.015    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      8382    0.008    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#      2600    0.010    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\game.py:335(getPossibleActions)
#       533    0.013    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\colorama\ansitowin32.py:260(convert_osc)
#       543    0.002    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:649(msg)
#      1452    0.005    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\platform\asyncio.py:225(add_callback)
#       533    0.001    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\iostream.py:587(_schedule_in_thread)
#      1181    0.003    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\game.py:378(__init__)
#       344    0.002    0.000    0.014    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\autograd\profiler.py:732(__enter__)
#     72760    0.014    0.000    0.014    0.000 {method 'encode' of 'str' objects}
#        24    0.000    0.000    0.014    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface_shared.py:453(_deliver_record)
#        24    0.000    0.000    0.013    0.001 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\lib\mailbox.py:443(_deliver_record)
#      7828    0.009    0.000    0.013    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\typing.py:392(inner)
#       533    0.001    0.000    0.013    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\ioloop.py:596(call_later)
#      3320    0.007    0.000    0.013    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\capture.py:128(getAgentPosition)
#      5934    0.013    0.000    0.013    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#       172    0.013    0.000    0.013    0.000 {built-in method torch._foreach_sqrt}
#        86    0.000    0.000    0.013    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\sdk\interface\interface_shared.py:85(_publish_partial_history)
#       344    0.001    0.000    0.012    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_ops.py:993(_must_dispatch_in_python)
#      1974    0.001    0.000    0.012    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\numpy\_core\_methods.py:51(_sum)
#       236    0.012    0.000    0.012    0.000 {built-in method torch.stack}
#       344    0.000    0.000    0.012    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\_ops.py:1105(__call__)
#       344    0.001    0.000    0.012    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\utils\_pytree.py:1197(tree_any)
#       344    0.012    0.000    0.012    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#        86    0.000    0.000    0.012    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\util.py:774(default)
#      2188    0.002    0.000    0.011    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\typing.py:1221(__instancecheck__)
#        86    0.001    0.000    0.011    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\wandb\util.py:556(json_friendly)
#       533    0.002    0.000    0.011    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\platform\asyncio.py:210(call_at)
#       344    0.011    0.000    0.011    0.000 {built-in method torch._foreach_add_}
#      4740    0.006    0.000    0.010    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\re\__init__.py:255(escape)
#       172    0.000    0.000    0.010    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\optim\optimizer.py:501(_group_tensors_by_device_and_dtype)
#       236    0.001    0.000    0.010    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\numpy\_core\fromnumeric.py:2349(sum)
#       172    0.010    0.000    0.010    0.000 {built-in method torch._foreach_lerp_}
#       595    0.002    0.000    0.010    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\threading.py:616(set)
#       172    0.001    0.000    0.010    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\torch\utils\_contextlib.py:113(decorate_context)
#       543    0.001    0.000    0.010    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\jupyter_client\session.py:645(msg_header)
# ...
#        12    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\_position_node_finder.py:28(mangled_name)
#         7    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:463(exception)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\queues.py:173(qsize)
#         5    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\asttokens\util.py:461(annotate_fstring_nodes)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'bytes' objects}
#        40    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2808(kind)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\ast.py:182(copy_location)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\futures.py:301(_get_loop)
#         1    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\matplotlib_inline\backend_inline.py:72(show)
#        16    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1728(_get_supported_file_loaders)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\traitlets\traitlets.py:3486(validate_elements)
#        14    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\executing.py:415(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2919(kwargs)
#        38    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2796(name)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\inputtransformer2.py:121(cell_magic)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:647(_check_name_wrapper)
#         7    0.000    0.000    0.000    0.000 {method 'co_positions' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:468(isawaitable)
#         3    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen os>:853(fsdecode)
#        16    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:1910(_timer_handle_cancelled)
#         9    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\executing\_position_node_finder.py:480(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#         6    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:258(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\3023797715.py:1(<module>)
#        12    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\ultratb.py:763(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.interrupt_main}
#         4    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:1486(<lambda>)
#         7    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\dis.py:199(_get_code_array)
#        14    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\utils.py:79(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\pygments\formatter.py:19(_lookup_style)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\ipkernel.py:270(finish_metadata)
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\display_trap.py:67(unset)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\queues.py:312(_put)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\traitlets\traitlets.py:4003(validate_elements)
#         6    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:659(_check_closed)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         4    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\queue.py:213(_put)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\queue.py:217(_get)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\queues.py:177(empty)
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\tokenize.py:488(generate_tokens)
#         7    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#         1    0.000    0.000    0.000    0.000 C:\Users\josse\AppData\Local\Temp\ipykernel_8784\3155788052.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\warnings.py:421(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:491(_verbose_message)
#         2    0.000    0.000    0.000    0.000 {function RcParams.__getitem__ at 0x0000017D0A013380}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:1487(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\futures.py:389(_call_check_cancel)
#         4    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rsplit' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\dateutil\parser\isoparser.py:383(_parse_tzstr)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         6    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX//agents/randomTeam.py:55(DummyAgent)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\dis.py:509(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'rjust' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'add_done_callback' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\ipkernel.py:731(_associate_new_top_level_threads_with)
#         4    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_event_loop}
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:299(success)
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _hashlib.compare_digest}
#        12    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:3089(parameters)
#         4    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\tornado\locks.py:224(clear)
#         3    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\distanceCalculator.py:94(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         3    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\logging\__init__.py:1369(disable)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:423(_finish_flush)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\logger.py:191(log_write)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.extension_suffixes}
#         2    0.000    0.000    0.000    0.000 {method 'get_loop' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:729(is_running)
#         8    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2800(default)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         4    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\selector_events.py:126(_process_self_data)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\tempfile.py:301(_gettempdir)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:599(__init__)
#         2    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:398(__get_result)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\inspect.py:2888(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\stack_data\core.py:194(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:296(__init__)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\interactiveshell.py:1157(_get_call_pdb)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1182(get_filename)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\zmq\eventloop\zmqstream.py:375(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\dateutil\parser\isoparser.py:26(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\IPython\core\hooks.py:88(synchronize_with_editor)
#         2    0.000    0.000    0.000    0.000 C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\asyncio\base_events.py:719(is_closed)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\ipkernel.py:308(execution_count)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\kernelbase.py:570(<lambda>)
#         2    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\venv\Lib\site-packages\ipykernel\compiler.py:81(get_tmp_hash_seed)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1157(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _signal.getsignal}
#         1    0.000    0.000    0.000    0.000 c:\Users\josse\OneDrive\Documenten\creditcontract\RL\RL_MARL_QMIX\textDisplay.py:27(initialize)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:653(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:990(create_module)
